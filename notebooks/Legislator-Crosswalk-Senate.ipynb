# %%
"""
legislators_tlo.html was copied from the source of
http://www.legis.state.tx.us/Search/BillSearchLegislatorList.aspx?ID=usrLegislatorsFolder$cboAuthor&Leg=85
"""

import pandas as pd
import re
import numpy as np

# from bs4 import BeautifulSoup

pattern = """\t<option value="(A[0-9]{3,5})">([^,]+)(, (.+))? \((H|S)-A[0-9]{3,5}\)</option>"""

fp = open('../data/inputs/legislators_tlo.html', encoding = 'utf-8')
lines = fp.readlines()

leg = []

for line in lines:
    # Regex applied to each line 
    match = re.search(pattern, line)
    legislator = [match.group(1), match.group(2), match.group(4), match.group(5)]
    if legislator[3] == "H":
        legislator[3] = "STATEREP"
    else: 
        legislator[3] = "STATESEN"
    leg.append(legislator)

# %%
def substitute(string):
    if type(string) == str:
        string = string.replace("&#233;", "é")
        string = string.replace("&quot;", '"')
        string = string.replace("&#225;", 'á')
        string = string.replace("&#237;", "í")
        string = string.replace("&#241;", "ñ")
    return string

for line in leg:
    line[1] = substitute(line[1])
    line[2] = substitute(line[2])
    if line[1] == "Lucio":
        line[1] = "Lucio Jr."

# %%
leg = pd.DataFrame(leg, columns = ["TLO_id","last_name","first_name", "ctaSeekOfficeCd"])

# %%
# splitting off nicknames and suffixes in the data from TLO

def parsenickname(first):
    nicknamePattern = ' [\"\(](\w+)[\"\)]$'
    try:
        match = re.search(nicknamePattern, first)
        newLast = first.split(match.group(0))[0]
        return newLast, match.group(1)
    except:
        return first, np.nan
    
def parsesuffix(last):
    suffixPattern = " (Jr\.|Sr\.|III)$"
    try:
        match = re.search(suffixPattern, last)
        newLast = last.split(match.group(0))[0]
        return newLast, match.group(1)
    except:
        return last, np.nan

leg["first_name"], leg["filerNameShort"] = zip(*leg["first_name"].map(parsenickname))
leg["last_name"], leg["suffixes"] = zip(*leg["last_name"].map(parsesuffix))
        
leg[:5]
# Out:
#   TLO_id last_name first_name ctaSeekOfficeCd filerNameShort suffixes
# 0  A2100     Allen       None        STATEREP            NaN      NaN
# 1  A2125    Alonzo       None        STATEREP            NaN      NaN
# 2  A2135  Alvarado       None        STATEREP            NaN      NaN
# 3  A2150    Anchia       None        STATEREP            NaN      NaN
# 4  A2155  Anderson    Charles        STATEREP            Doc      NaN

# %%
# This loads a file from an Open States bulk download
# Not sure that {"district": object} is the right choice, but I wanted integers with NaN allowed.

openstates = pd.read_csv("../data/inputs/openstates/2017-06-02-tx-csv/tx_legislators.csv", index_col = "leg_id",
                        dtype = {"district": object})

openstates["first_name"], openstates["filerNameShort"] = zip(*openstates["first_name"].map(parsenickname))

# %%
# some of the openstates rows include the TLO id as part of the URL to the legislator's photo.

import re

def parseTLO(url):
    urlPattern = "small\/(A[0-9]{3,5})\.jpg$"
    try:
        match = re.search(urlPattern, url)
        return match.group(1)
    except:
        return np.nan
    
openstates["TLO_id"] = (openstates["photo_url"].map(parseTLO))

# %%
openstates[openstates["TLO_id"].isnull()][openstates["chamber"] == "upper"]
# Out:
# /Users/Matt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#                   full_name  first_name middle_name   last_name suffixes  \
# leg_id
# TXL000198  Eddie Lucio, Jr.  Eduardo A.         NaN       Lucio      Jr.
# TXL000312     José Menéndez        José         NaN    Menéndez      NaN
# TXL000705   Dawn Buckingham        Dawn         NaN  Buckingham      NaN
# TXL000707   Borris L. Miles   Borris L.         NaN       Miles      NaN
# TXL000716      Bryan Hughes       Bryan         NaN      Hughes      NaN
#
#           nickname active state chamber district       party  \
# leg_id
# TXL000198      NaN   True    tx   upper       27    Democrat
# TXL000312      NaN   True    tx   upper       26    Democrat
# TXL000705      NaN   True    tx   upper       24  Republican
# TXL000707      NaN   True    tx   upper       13    Democrat
# TXL000716      NaN   True    tx   upper        1  Republican
#
#                                                    photo_url  \
# leg_id
# TXL000198  http://www.house.state.tx.us/photos/members/36...
# TXL000312  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000705                                                NaN
# TXL000707                                                NaN
# TXL000716                                                NaN
#
#                            created_at                  updated_at  \
# leg_id
# TXL000198  2010-06-19 03:51:42.083000  2017-06-01 10:38:26.283000
# TXL000312  2010-06-19 03:51:42.467000  2017-06-01 10:38:26.641000
# TXL000705  2017-01-18 03:03:18.301000  2017-06-01 10:38:26.639000
# TXL000707  2017-01-18 03:03:18.403000  2017-06-01 10:38:26.414000
# TXL000716  2017-01-27 05:42:08.204000  2017-06-01 10:38:26.497000
#
#           filerNameShort TLO_id
# leg_id
# TXL000198          Eddie    NaN
# TXL000312            NaN    NaN
# TXL000705            NaN    NaN
# TXL000707            NaN    NaN
# TXL000716            NaN    NaN

# %%
# just setting the remaining 5 senators' TLO_id directly.

tloID = {"TXL000198": "A1300", 
        "TXL000312": "A1110",
        "TXL000705": "A1125",
        "TXL000707": "A1115",
        "TXL000716": "A1135"}

for k in tloID.keys():
    openstates.set_value(k, "TLO_id", tloID[k])

# %%
openstates[openstates["chamber"] == "upper"]
# Out:
#                      full_name  first_name middle_name    last_name suffixes  \
# leg_id
# TXL000190          Craig Estes       Craig         NaN        Estes      NaN
# TXL000195        Juan Hinojosa        Juan         NaN     Hinojosa      NaN
# TXL000196         Joan Huffman        Joan         NaN      Huffman      NaN
# TXL000198     Eddie Lucio, Jr.  Eduardo A.         NaN        Lucio      Jr.
# TXL000199          Jane Nelson        Jane         NaN       Nelson      NaN
# TXL000200       Robert Nichols      Robert         NaN      Nichols      NaN
# TXL000203          Kel Seliger         Kel         NaN      Seliger      NaN
# TXL000206        Carlos Uresti   Carlos I.         NaN       Uresti      NaN
# TXL000208          Kirk Watson        Kirk         NaN       Watson      NaN
# TXL000210           Royce West       Royce         NaN         West      NaN
# TXL000211        John Whitmire        John         NaN     Whitmire      NaN
# TXL000213     Judith Zaffirini      Judith         NaN    Zaffirini      NaN
# TXL000240    Brandon Creighton     Brandon         NaN    Creighton      NaN
# TXL000271        Kelly Hancock       Kelly         NaN      Hancock      NaN
# TXL000297       Lois Kolkhorst     Lois W.         NaN    Kolkhorst      NaN
# TXL000312        José Menéndez        José         NaN     Menéndez      NaN
# TXL000349         Larry Taylor       Larry         NaN       Taylor      NaN
# TXL000350           Van Taylor         Van         NaN       Taylor      NaN
# TXL000364       Brian Birdwell       Brian         NaN     Birdwell      NaN
# TXL000400        Charles Perry     Charles         NaN        Perry      NaN
# TXL000405   Charles Schwertner     Charles         NaN   Schwertner      NaN
# TXL000414  José R. Rodríguez\t        José          R.  Rodríguez\t      NaN
# TXL000419       Donna Campbell       Donna         NaN     Campbell      NaN
# TXL000473     Sylvia R. Garcia   Sylvia R.         NaN       Garcia      NaN
# TXL000479         Don Huffines         Don         NaN     Huffines      NaN
# TXL000482     Paul Bettencourt        Paul         NaN  Bettencourt      NaN
# TXL000487         Konni Burton       Konni         NaN       Burton      NaN
# TXL000503             Bob Hall         Bob         NaN         Hall      NaN
# TXL000705      Dawn Buckingham        Dawn         NaN   Buckingham      NaN
# TXL000707      Borris L. Miles   Borris L.         NaN        Miles      NaN
# TXL000716         Bryan Hughes       Bryan         NaN       Hughes      NaN
#
#           nickname active state chamber district       party  \
# leg_id
# TXL000190      NaN   True    tx   upper       30  Republican
# TXL000195      NaN   True    tx   upper       20    Democrat
# TXL000196      NaN   True    tx   upper       17  Republican
# TXL000198      NaN   True    tx   upper       27    Democrat
# TXL000199      NaN   True    tx   upper       12  Republican
# TXL000200      NaN   True    tx   upper        3  Republican
# TXL000203      NaN   True    tx   upper       31  Republican
# TXL000206      NaN   True    tx   upper       19    Democrat
# TXL000208      NaN   True    tx   upper       14    Democrat
# TXL000210      NaN   True    tx   upper       23    Democrat
# TXL000211      NaN   True    tx   upper       15    Democrat
# TXL000213      NaN   True    tx   upper       21    Democrat
# TXL000240      NaN   True    tx   upper        4  Republican
# TXL000271      NaN   True    tx   upper        9  Republican
# TXL000297      NaN   True    tx   upper       18  Republican
# TXL000312      NaN   True    tx   upper       26    Democrat
# TXL000349      NaN   True    tx   upper       11  Republican
# TXL000350      NaN   True    tx   upper        8  Republican
# TXL000364      NaN   True    tx   upper       22  Republican
# TXL000400      NaN   True    tx   upper       28  Republican
# TXL000405      NaN   True    tx   upper        5  Republican
# TXL000414      NaN   True    tx   upper       29    Democrat
# TXL000419      NaN   True    tx   upper       25  Republican
# TXL000473      NaN   True    tx   upper        6    Democrat
# TXL000479      NaN   True    tx   upper       16  Republican
# TXL000482      NaN   True    tx   upper        7  Republican
# TXL000487      NaN   True    tx   upper       10  Republican
# TXL000503      NaN   True    tx   upper        2  Republican
# TXL000705      NaN   True    tx   upper       24  Republican
# TXL000707      NaN   True    tx   upper       13    Democrat
# TXL000716      NaN   True    tx   upper        1  Republican
#
#                                                    photo_url  \
# leg_id
# TXL000190  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000195  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000196  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000198  http://www.house.state.tx.us/photos/members/36...
# TXL000199  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000200  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000203  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000206  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000208  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000210  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000211  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000213  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000240  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000271  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000297  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000312  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000349  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000350  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000364  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000400  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000405  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000414  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000419  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000473  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000479  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000482  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000487  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000503  http://www.legdir.legis.state.tx.us/FlashCardD...
# TXL000705                                                NaN
# TXL000707                                                NaN
# TXL000716                                                NaN
#
#                            created_at                  updated_at  \
# leg_id
# TXL000190  2010-06-19 03:51:42.063000  2017-06-01 10:38:26.268000
# TXL000195  2010-06-19 03:51:42.076000  2017-06-01 10:38:26.808000
# TXL000196  2010-06-19 03:51:42.078000  2017-06-01 10:38:26.752000
# TXL000198  2010-06-19 03:51:42.083000  2017-06-01 10:38:26.283000
# TXL000199  2010-06-19 03:51:42.086000  2017-06-01 10:38:26.740000
# TXL000200  2010-06-19 03:51:42.088000  2017-06-01 10:38:26.798000
# TXL000203  2010-06-19 03:51:42.095000  2017-06-01 10:38:26.762000
# TXL000206  2010-06-19 03:51:42.103000  2017-06-01 10:38:26.767000
# TXL000208  2010-06-19 03:51:42.107000  2017-06-01 10:38:26.769000
# TXL000210  2010-06-19 03:51:42.112000  2017-06-01 10:38:26.772000
# TXL000211  2010-06-19 03:51:42.115000  2017-06-01 10:38:26.774000
# TXL000213  2010-06-19 03:51:42.131000  2017-06-01 10:38:26.442000
# TXL000240  2010-06-19 03:51:42.210000  2017-06-01 10:38:26.803000
# TXL000271  2010-06-19 03:51:42.331000  2017-06-01 10:38:26.805000
# TXL000297  2010-06-19 03:51:42.408000  2017-06-01 10:38:26.810000
# TXL000312  2010-06-19 03:51:42.467000  2017-06-01 10:38:26.641000
# TXL000349  2010-06-19 03:51:42.610000  2017-06-01 10:38:26.764000
# TXL000350  2010-06-19 03:51:42.613000  2017-06-01 10:38:26.419000
# TXL000364  2010-07-17 08:38:47.948000  2017-06-01 10:38:26.747000
# TXL000400  2011-01-14 22:24:08.416000  2017-06-01 10:38:26.813000
# TXL000405  2011-01-14 22:24:08.419000  2017-06-01 10:38:26.760000
# TXL000414  2011-01-14 22:24:08.575000  2017-06-01 10:38:26.815000
# TXL000419  2013-01-09 00:29:35.053000  2017-06-01 10:38:26.288000
# TXL000473  2013-03-12 18:18:45.435000  2017-06-01 10:35:57.613000
# TXL000479  2015-01-14 00:53:27.338000  2017-06-01 10:38:26.432000
# TXL000482  2015-01-14 00:53:27.393000  2017-06-01 10:38:26.745000
# TXL000487  2015-01-14 00:53:27.536000  2017-06-01 10:38:26.492000
# TXL000503  2015-01-14 00:53:27.965000  2017-06-01 10:38:26.801000
# TXL000705  2017-01-18 03:03:18.301000  2017-06-01 10:38:26.639000
# TXL000707  2017-01-18 03:03:18.403000  2017-06-01 10:38:26.414000
# TXL000716  2017-01-27 05:42:08.204000  2017-06-01 10:38:26.497000
#
#           filerNameShort TLO_id
# leg_id
# TXL000190            NaN  A1180
# TXL000195           Chuy  A1250
# TXL000196            NaN  A1260
# TXL000198          Eddie  A1300
# TXL000199            NaN  A1450
# TXL000200            NaN  A1400
# TXL000203            NaN  A1460
# TXL000206            NaN  A1605
# TXL000208            NaN  A1610
# TXL000210            NaN  A1625
# TXL000211            NaN  A1650
# TXL000213            NaN  A1700
# TXL000240            NaN  A1040
# TXL000271            NaN  A1015
# TXL000297            NaN  A1105
# TXL000312            NaN  A1110
# TXL000349            NaN  A1030
# TXL000350            NaN  A1085
# TXL000364            NaN  A1080
# TXL000400            NaN  A1045
# TXL000405            NaN  A1025
# TXL000414            NaN  A1005
# TXL000419            NaN  A1010
# TXL000473            NaN  A1035
# TXL000479            NaN  A1095
# TXL000482            NaN  A1055
# TXL000487            NaN  A1090
# TXL000503            NaN  A1050
# TXL000705            NaN  A1125
# TXL000707            NaN  A1115
# TXL000716            NaN  A1135

# %%
tloOpen = pd.merge(leg, openstates.reset_index(), how='left', on='TLO_id')

# %%
senate = tloOpen[tloOpen["ctaSeekOfficeCd"] == "STATESEN"]

# %%
# This loads a file from the Texas Election Commission

tx = pd.read_csv("../data/inputs/TEC_CF_CSV/filers.csv")
# Out:
# /Users/Matt/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (9,38,43,50,54,79,80,109,112,131) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
tx = tx[tx["filerTypeCd"] == 'COH']

# %%
# removed 'STATEREP',  to focus on Senate
# removed [tx['ctaSeekOfficeCd'].isin(['STATESEN'], changed to filerHoldOfficeCd 

txRep = tx[tx['filerHoldOfficeCd'].isin(['STATESEN'])][tx['filerFilerpersStatusCd'] != "NOT_OFFICEHOLDER"]
# Out:
# /Users/Matt/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
senate[:5]
# Out:
#     TLO_id  last_name_x first_name_x ctaSeekOfficeCd filerNameShort_x  \
# 150  A1055  Bettencourt         None        STATESEN              NaN
# 151  A1080     Birdwell         None        STATESEN              NaN
# 152  A1125   Buckingham         None        STATESEN              NaN
# 153  A1090       Burton         None        STATESEN              NaN
# 154  A1010     Campbell         None        STATESEN              NaN
#
#     suffixes_x     leg_id         full_name first_name_y middle_name  \
# 150        NaN  TXL000482  Paul Bettencourt         Paul         NaN
# 151        NaN  TXL000364    Brian Birdwell        Brian         NaN
# 152        NaN  TXL000705   Dawn Buckingham         Dawn         NaN
# 153        NaN  TXL000487      Konni Burton        Konni         NaN
# 154        NaN  TXL000419    Donna Campbell        Donna         NaN
#
#           ...        nickname active state chamber district       party  \
# 150       ...             NaN   True    tx   upper        7  Republican
# 151       ...             NaN   True    tx   upper       22  Republican
# 152       ...             NaN   True    tx   upper       24  Republican
# 153       ...             NaN   True    tx   upper       10  Republican
# 154       ...             NaN   True    tx   upper       25  Republican
#
#                                              photo_url  \
# 150  http://www.legdir.legis.state.tx.us/FlashCardD...
# 151  http://www.legdir.legis.state.tx.us/FlashCardD...
# 152                                                NaN
# 153  http://www.legdir.legis.state.tx.us/FlashCardD...
# 154  http://www.legdir.legis.state.tx.us/FlashCardD...
#
#                      created_at                  updated_at filerNameShort_y
# 150  2015-01-14 00:53:27.393000  2017-06-01 10:38:26.745000              NaN
# 151  2010-07-17 08:38:47.948000  2017-06-01 10:38:26.747000              NaN
# 152  2017-01-18 03:03:18.301000  2017-06-01 10:38:26.639000              NaN
# 153  2015-01-14 00:53:27.536000  2017-06-01 10:38:26.492000              NaN
# 154  2013-01-09 00:29:35.053000  2017-06-01 10:38:26.288000              NaN
#
# [5 rows x 22 columns]

# %%
txRep[:5]
# Out:
#      recordType  filerIdent filerTypeCd  \
# 40        FILER       13805         COH
# 1772      FILER       19581         COH
# 2306      FILER       20257         COH
# 2691      FILER       20673         COH
# 2974      FILER       20971         COH
#
#                                   filerName unexpendContribFilerFlag  \
# 40           Hinojosa, Juan (The Honorable)                        N
# 1772         Whitmire, John (The Honorable)                        N
# 2306  Lucio Jr., Eduardo A. (The Honorable)                        N
# 2691           Nelson, Jane (The Honorable)                        N
# 2974      Zaffirini, Judith (The Honorable)                        N
#
#      modifiedElectCycleFlag filerJdiCd committeeStatusCd ctaSeekOfficeCd  \
# 40                        N        NaN               NaN        STATESEN
# 1772                      N        NaN               NaN        STATESEN
# 2306                      N        NaN               NaN        STATESEN
# 2691                      N        NaN               NaN        STATESEN
# 2974                      N        NaN               NaN        STATESEN
#
#      ctaSeekOfficeDistrict         ...           chairMailingAddr2  \
# 40                      20         ...                         NaN
# 1772                    15         ...                         NaN
# 2306                    27         ...                         NaN
# 2691                    12         ...                         NaN
# 2974                    21         ...                         NaN
#
#      chairMailingCity chairMailingStateCd chairMailingCountyCd  \
# 40                NaN                 NaN                  NaN
# 1772              NaN                 NaN                  NaN
# 2306              NaN                 NaN                  NaN
# 2691              NaN                 NaN                  NaN
# 2974              NaN                 NaN                  NaN
#
#      chairMailingCountryCd chairMailingPostalCode chairMailingRegion  \
# 40                     NaN                    NaN                NaN
# 1772                   NaN                    NaN                NaN
# 2306                   NaN                    NaN                NaN
# 2691                   NaN                    NaN                NaN
# 2974                   NaN                    NaN                NaN
#
#      chairPrimaryUsaPhoneFlag chairPrimaryPhoneNumber chairPrimaryPhoneExt
# 40                        NaN                     NaN                  NaN
# 1772                      NaN                     NaN                  NaN
# 2306                      NaN                     NaN                  NaN
# 2691                      NaN                     NaN                  NaN
# 2974                      NaN                     NaN                  NaN
#
# [5 rows x 132 columns]

# %%
txRep = txRep.rename(columns={"filerHoldOfficeDistrict": "district"})

# txRep["district"].describe()

# %%
allThree = pd.merge(senate, txRep, how='left', on = 'district')

# %%
allThree[["first_name_x", "last_name_x", "full_name", "first_name_y", "last_name_y", 
          "filerName"]]
# Out:
#    first_name_x  last_name_x            full_name first_name_y  last_name_y  \
# 0          None  Bettencourt     Paul Bettencourt         Paul  Bettencourt
# 1          None     Birdwell       Brian Birdwell        Brian     Birdwell
# 2          None   Buckingham      Dawn Buckingham         Dawn   Buckingham
# 3          None       Burton         Konni Burton        Konni       Burton
# 4          None     Campbell       Donna Campbell        Donna     Campbell
# 5          None    Creighton    Brandon Creighton      Brandon    Creighton
# 6          None        Estes          Craig Estes        Craig        Estes
# 7          None       Garcia     Sylvia R. Garcia    Sylvia R.       Garcia
# 8          None         Hall             Bob Hall          Bob         Hall
# 9          None      Hancock        Kelly Hancock        Kelly      Hancock
# 10         None     Hinojosa        Juan Hinojosa         Juan     Hinojosa
# 11         None     Huffines         Don Huffines          Don     Huffines
# 12         None      Huffman         Joan Huffman         Joan      Huffman
# 13         None       Hughes         Bryan Hughes        Bryan       Hughes
# 14         None    Kolkhorst       Lois Kolkhorst      Lois W.    Kolkhorst
# 15         None        Lucio     Eddie Lucio, Jr.   Eduardo A.        Lucio
# 16         None     Menéndez        José Menéndez         José     Menéndez
# 17         None        Miles      Borris L. Miles    Borris L.        Miles
# 18         None       Nelson          Jane Nelson         Jane       Nelson
# 19         None      Nichols       Robert Nichols       Robert      Nichols
# 20         None      Patrick          Dan Patrick          Dan      Patrick
# 21         None        Perry        Charles Perry      Charles        Perry
# 22         None    Rodríguez  José R. Rodríguez\t         José  Rodríguez\t
# 23         None   Schwertner   Charles Schwertner      Charles   Schwertner
# 24         None      Seliger          Kel Seliger          Kel      Seliger
# 25        Larry       Taylor         Larry Taylor        Larry       Taylor
# 26          Van       Taylor           Van Taylor          Van       Taylor
# 27         None       Uresti        Carlos Uresti    Carlos I.       Uresti
# 28         None       Watson          Kirk Watson         Kirk       Watson
# 29         None         West           Royce West        Royce         West
# 30         None     Whitmire        John Whitmire         John     Whitmire
# 31         None    Zaffirini     Judith Zaffirini       Judith    Zaffirini
#
#                                   filerName
# 0         Bettencourt, Paul (The Honorable)
# 1        Birdwell, Brian D. (The Honorable)
# 2       Buckingham, Dawn C. (The Honorable)
# 3          Burton, Konni L. (The Honorable)
# 4      Campbell M.D., Donna (The Honorable)
# 5     Creighton, C. Brandon (The Honorable)
# 6              Estes, Craig (The Honorable)
# 7         Garcia, Sylvia R. (The Honorable)
# 8       Hall III, Robert L. (The Honorable)
# 9         Hancock, Kelly G. (The Honorable)
# 10           Hinojosa, Juan (The Honorable)
# 11      Huffines, Donald B. (The Honorable)
# 12         Huffman, C. Joan (The Honorable)
# 13         Hughes, D. Bryan (The Honorable)
# 14       Kolkhorst, Lois W. (The Honorable)
# 15    Lucio Jr., Eduardo A. (The Honorable)
# 16           Menendez, Jose (The Honorable)
# 17        Miles, Borris Lee (The Honorable)
# 18             Nelson, Jane (The Honorable)
# 19      Nichols, Robert Lee (The Honorable)
# 20                                      NaN
# 21        Perry, Charles L. (The Honorable)
# 22  Rodriguez, Jose Roberto (The Honorable)
# 23      Schwertner, Charles (The Honorable)
# 24       Seliger, Kelton G. (The Honorable)
# 25         Taylor, Larry W. (The Honorable)
# 26      Taylor, Nicholas V. (The Honorable)
# 27        Uresti, Carlos I. (The Honorable)
# 28          Watson, Kirk P. (The Honorable)
# 29              West, Royce (The Honorable)
# 30           Whitmire, John (The Honorable)
# 31        Zaffirini, Judith (The Honorable)

# %%
def s (string):
    return string.strip()

allThree["full_name"] = allThree["full_name"].apply(s)

# %%
answer = allThree[pd.notnull(allThree['filerName'])]

# %%
answer[:1]
# Out:
#   TLO_id  last_name_x first_name_x ctaSeekOfficeCd_x filerNameShort_x  \
# 0  A1055  Bettencourt         None          STATESEN              NaN
#
#   suffixes_x     leg_id         full_name first_name_y middle_name  \
# 0        NaN  TXL000482  Paul Bettencourt         Paul         NaN
#
#           ...          chairMailingAddr2 chairMailingCity chairMailingStateCd  \
# 0         ...                        NaN              NaN                 NaN
#
#   chairMailingCountyCd chairMailingCountryCd chairMailingPostalCode  \
# 0                  NaN                   NaN                    NaN
#
#   chairMailingRegion chairPrimaryUsaPhoneFlag chairPrimaryPhoneNumber  \
# 0                NaN                      NaN                     NaN
#
#   chairPrimaryPhoneExt
# 0                  NaN
#
# [1 rows x 153 columns]

# %%
answerShort = answer[["TLO_id", "leg_id", "filerIdent", "full_name", "first_name_y", "filerNameShort", "last_name_x", "suffixes_x", "party", "district"]]

# %%
answerShort = answerShort.rename(columns={"first_name_y": "first_name", "last_name_x": "last_name", 
                                "filerNameShort": "nickname", "suffixes_x": "suffixes"})

# %%
answerShort["filerIdent"] = answerShort["filerIdent"].astype(int)

# %%
answerShort = answerShort.set_index("TLO_id")

# %%
answerShort.to_csv("../data/senateCrosswalk.csv")
