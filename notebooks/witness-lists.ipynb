# %%
# The purpose of this notebook is to get a CSV of tabular data based on the witness lists.

# I used wget to collect ftp.legis.state.tx.us/bills/85R/witlistbill/html/senate_bills/
# and put them all together in a directory called '/bills/85R/witlistbill/html/senate_bills/'
# These files are not being stored in the github repo because they're too big.

# The published lists are in HTML exported from Microsoft Word, so the markup reflects 
# intended page layout rather than content.

from bs4 import BeautifulSoup
import re

# %%
endWithState = re.compile(r'[^\(](AL|AK|AS|AZ|AR|CA|CO|CT|DE|DC|FM|FL|GA|GU|HI|ID|IL|IN|IA|KS|KY|LA|ME|MH|MD|MA|MI|MN|MS|MO|MT|NE|NV|NH|NJ|NM|NY|NC|ND|MP|OH|OK|OR|PW|PA|PR|RI|SC|SD|TN|TX|Texas|UT|VT|VI|VA|WA|WV|WI|WY)\n?$')

# %%
def addName(line):
    flags = [re.IGNORECASE, re.DOTALL]
    regexes = [r"^((?:[\w\'\-]+\s)*[\w\'\-]+),\n((?:\w+\s)*\w+)\xa0\xa0 ", 
              r"^((?:[\w\'\-]+\s)*[\w\'\-]+),\n((?:\w+\s)*\w+)\s+\(", 
              r"^((?:[\w\'\-]+\s)*[\w\'\-]+),[\n\s]+((?:[A-Z]\.)+)\s\s",
              r'^((?:\w+\s)*\w+),\s+([^\(\s]+) ', 
              r'^((?:\w+\s)*\w+),\s+((?:\w+\s)*\w+)  '] # third one for initials as first name
    partial = r'^(\w+)\s+\n\('  # Matches where someone put just a surname
    for f in flags:
        for r in regexes:
            nameRe = re.compile(r, f)
            match = re.search(nameRe, line[0])
            if match:
                extension = [match.group(1).strip(), match.group(2).strip()]
                return extension
    
    # A separate case for the partial match
    nameRe = re.compile(partial)
    if re.search(nameRe, line[0]):
        match = re.search(nameRe, line[0])
        extension = [match.group(1).strip(), None]
        return extension
    
    # And a third case to leave the fields blank
    extension = [None, None]
    return extension

def addTitle(line):
    regexes = [r',\s(?:(?:\w+\s)*\w+)\s+(.+)\s*\(also providing', r',\s(?:(?:\w+\s)*\w+)\s+(.+)\s*\(',
               '^(?:(?:\w+\s)*\w+),\s+(?:(?:\w+\s)*\w+)\s\s+(.+)\(also providing',
               '^(?:(?:\w+\s)*\w+),\s+(?:(?:\w+\s)*\w+)\s\s+(.+)\('
              #  r'^.+,\n.+\s+(.+)\s+\(also providing', r'^.+,\n.+\s+(.+)\s+\(',
              # ',\n?.+\xa0\xa0 ((?:\w+\s)*\w+)\s+(\(also providing written testimony\))?\s+\('
              ]
    for r in regexes:
        titleRe = re.compile(r)
        match = re.search(titleRe, line[0])
        if match:
            extension = [match.group(1).strip()]
            return extension
    extension = [None]
    return extension

def addOrg(line):
    flags = [re.IGNORECASE, re.DOTALL]
    regexes = [r'written testimony\)\s+\((.+)\)\s*(,|$)', 
              r'\s+\((.+)\)\s*(,|$)',]
    for f in flags:
        for r in regexes:
            orgRe = re.compile(r, f)
            match = re.search(orgRe, line[0])
            if match:
                extension = [match.group(1).strip()]
                return extension
    extension = [None]
    return extension

def addCity(line):
    extension = [None, None]
    cityRe = re.compile(r'\)\s?,\s(.*),\s(.*)$')
    match = re.search(cityRe, line[0])
    if match:
        extension = [match.group(1).strip(), match.group(2).strip()]
    return extension

addName(["Parks,\nUrsula (Legislative Budget Board)","HB 2","For"])
# Out:
# ['Parks', 'Ursula']

# %%
# I haven't made a corresponding function for Senate bills. Instead I
# reused this same function, which means the Senate data probably has
# more errors.

def HBWitness(witnessList):
    fp = open(witnessList, encoding = 'cp1252')
    soup = BeautifulSoup(fp.read(), "html.parser")
    
    # each printed page has a class with Wordsection plus a number
    pages = soup.select("div[class^=WordSection]") 
    
    indent = re.compile(r"^\s{30}") # whitespace should mean it's a listing, page number, or the heading "WITNESS LIST"
    forStance = re.compile(r'^\s+FOR\s?:', re.IGNORECASE) # i flag means case-insensitive
    againstStance = re.compile(r'^\s+AGAINST\s?:', re.IGNORECASE)
    onStance = re.compile(r'^\s+ON\s?:', re.IGNORECASE)

    wit = []
    stance = "For"
    for page in pages:
        witpage = []
        pp = page.select("p")
        for line in pp:
            text = line.get_text()
            if re.match(forStance, text):
                stance = "For"
            if re.match(againstStance, text):
                stance = "Against"
            if re.match(onStance, text):
                stance = "On"
            if re.match(indent, text):
                witpage.append([line.get_text(), stance])
        wit.extend(witpage[1:-1])

    bill = soup.find('span', {'style':"color:windowtext;text-decoration:none"}) # identifies the bill
    bill = bill.get_text()
    for line in wit:
        line.extend([bill.strip()])
    
    wit = [x for x in wit if x != None]
    
    return wit

# %%
def mergelines(wit):
    changed = 0    
    newList = []
    badList = []
    tooShort = re.compile("^\w+\)?,?\s?(AL|AK|AS|AZ|AR|CA|CO|CT|DE|DC|FM|FL|GA|GU|HI|ID|IL\
                        |IN|IA|KS|KY|LA|ME|MH|MD|MA|MI|MN|MS|MO|MT|NE|NV|NH|NJ|NM|NY|NC\
                        |ND|MP|OH|OK|OR|PW|PA|PR|RI|SC|SD|TN|TX|Texas|UT|VT|VI|VA|WA|WV|WI|WY)?\n?$") # line shouldn't have just one word
    for line in wit:
        line[0] = line[0].strip()
    
    for line in wit[:-1]:
        lineIndex = wit.index(line)
        
        # Lines will get merged if they pass any of the three tests. Only if not will a line be accepted.
        
        if re.search(endWithState, wit[lineIndex + 1][0]) and not re.search(endWithState, line[0]) \
        and addName(line) != [None, None] and addName(wit[lineIndex + 1]) == [None, None]:
            newList.append([line[0] + " " + wit[lineIndex + 1][0], line[1], line[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
        
        elif re.search(tooShort, wit[lineIndex + 1][0].strip()):
            newList.append([line[0] + " " + wit[lineIndex + 1][0], line[1], line[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
            
        elif line[0].count(')') != line[0].count('(') \
        and wit[lineIndex + 1][0].count(')') != wit[lineIndex + 1][0].count('(') \
        and addName(line) != [None, None] and not re.search(endWithState, line[0]):
            newList.append([line[0] + " " + wit[lineIndex + 1][0], line[1], line[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
            
        elif line[0].count(')') != line[0].count('(') \
        and wit[lineIndex + 1][0].count(')') != wit[lineIndex + 1][0].count('(') \
        and addName(line) != [None, None] \
        and addName(wit[lineIndex + 1]) == [None,None]:
            newList.append([line[0] + " " + wit[lineIndex + 1][0], line[1], line[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
            
        else:
            newList.append(line[0:3])
    
    answer = [x for x in newList if x not in badList]
    
    return answer

# %%
import shutil, os

def extractRows(folderName):
    
    houseWit = []
    for folderName, subfolders, filenames in os.walk(folderName):
        for filename in filenames:
            if filename != ".DS_Store":
                source = folderName + filename
                wit = HBWitness(source)
                # print(str(changed) + " lines changed.")
                houseWit.extend(wit)
    return houseWit
            
folderName = 'bills/85R/witlistbill/html/house_bills/'
houseWit = extractRows(folderName)

# %%
# houseWit[:5]

# %%
# trying to rejoin entries split across lines
newList = mergelines(houseWit)

newList = mergelines(newList) # Will doing it twice catch 3-line entries?

# %%
# Adding the last six fields to each row

for line in newList:
    line.extend(addName(line))
    line.extend(addTitle(line))
    line.extend(addOrg(line))
    line.extend(addCity(line))

# %%
# pandas is only used for data exploration. 
# There are definitely still errors.

import pandas as pd
pd.options.display.max_colwidth = 500


df = pd.DataFrame(newList, columns=list(['raw', 'position', 'bill', 'last','first','title', 'org','city','state']))

# %%
# df[df['bill'] == "HB 3025"]

# %%
# These are the lines most likely to have problems

df[pd.isnull(df['org'])]
# df.first.isnull()
# Out:
#                                                                                                 raw  \
# 24         Van\nDen Bent, Jerre   Physical therapist  (also providing written testimony) \n(Therapy
# 25                                                                               2000),\nDallas, TX
# 296              Roman\nMD, Heidi   Ambulatory Medical Director  (Rees-Jones Center for Foster Care
# 297                Excellence\nat Children's Health and UT Southwestern Medical Center), Dallas, TX
# 982         Ramon\nButts, Edna   Director, Intergovernmental Relations & Policy Oversight \n(Austin
# 983                                                                               ISD),\nAustin, TX
# 5232                                                                               Houston,\nTx, TX
# 5260                 Gear\nJr., Bob   Director, Texas Veterans Leadership Program  (Texas Workforce
# 5261                                                                       Commission),\nAustin, TX
# 5436             Morrow\nPhD, Rosemary   Clinical Asst. Professor; UTeach-Liberal Arts Program, The
# 9243                                                                             Austin,\nTexas, TX
# 10351              De\nMayo, Mandy   Executive Director  (also providing written testimony)  (Self;
# 10352                                                                    HousingWorks),\nAustin, TX
# 10709                                                                  Foundation),\nFredericksburg
# 12269                                                                            Austin,\nTexas, TX
# 13272              Guillory,\nM.D., MPH, Charleta (March of Dimes, Texas Medical Association, Texas
# 13273                                            Pediatric\nSociety, Texas Public Health Coalition)
# 14016    Hopper,\nCraig   Chair, Estate & Trust Legislative Affairs Committee, Real Estate\nProbate
# 14017        Trust\nLaw (REPTL) Section of State Bar of Texas  (Self; SBOT REPTL; Self- probate and
# 14018                                                        estate\nplanning attorney), Austin, TX
# 15319                                      Academy\nof Family Physicians, MOD, TX Care for Childre)
# 15354           Neavel,\nMD, Celia (Self; Texas Pediatric Society, Texas Medical Association, Texas
# 15355  Association\nof Obstretics and Gynecology, Texas Academy of Family Practice, March of Dimes)
# 17042           Neavel,\nMD, Celia (Self; Texas Pediatric Society, Texas Medical Association, Texas
# 17043  Association\nof Obstretics and Gynecology, Texas Academy of Family Practice, March of Dimes)
# 17073                                      Academy\nof Family Physicians, MOD, TX Care for Childre)
# 17143      Neavel,\nCelia   Dr  (also providing written testimony)  (Self; Texas Pediatric Society,
# 17144         Texas\nMedical Asocciation, Texas Academy of Family Physicians, March of Dimes, Texas
# 17145                                        Association\nof Obstetrics and Gynecology), Austin, TX
# 17548                                                Anesthesiologists,\nTexas Medical Association)
# 18040           Neavel,\nMD, Celia (Self; Texas Pediatric Society, Texas Medical Association, Texas
# 18041  Association\nof Obstretics and Gynecology, Texas Academy of Family Practice, March of Dimes)
# 18060                                      Academy\nof Family Physicians, MOD, TX Care for Childre)
#
#       position     bill                                       last   first  \
# 24          On     HB 2                                       None    None
# 25          On     HB 2                                       None    None
# 296         On     HB 7                                       None    None
# 297         On     HB 7                                       None    None
# 982         On    HB 21                                       None    None
# 983         On    HB 21                                       None    None
# 5232       For   HB 490                                    Houston     Tx,
# 5260        On   HB 493                                       None    None
# 5261        On   HB 493                                       None    None
# 5436        On   HB 515                                       None    None
# 9243        On  HB 1260                                     Austin  Texas,
# 10351  Against  HB 1449                                       None    None
# 10352  Against  HB 1449                                       None    None
# 10709      For  HB 1492                                       None    None
# 12269       On  HB 1724                                     Austin  Texas,
# 13272      For  HB 1908                                   Guillory   M.D.,
# 13273      For  HB 1908                         Pediatric\nSociety   Texas
# 14016      For  HB 1974                                     Hopper   Craig
# 14017      For  HB 1974                                       None    None
# 14018      For  HB 1974                                       None    None
# 15319      For  HB 2135              Academy\nof Family Physicians    MOD,
# 15354      For  HB 2135                                     Neavel     MD,
# 15355      For  HB 2135  Association\nof Obstretics and Gynecology   Texas
# 17042      For  HB 2466                                     Neavel     MD,
# 17043      For  HB 2466  Association\nof Obstretics and Gynecology   Texas
# 17073      For  HB 2466              Academy\nof Family Physicians    MOD,
# 17143      For  HB 2466                                     Neavel   Celia
# 17144      For  HB 2466                 Texas\nMedical Asocciation   Texas
# 17145      For  HB 2466                                       None    None
# 17548      For  HB 2525                          Anesthesiologists   Texas
# 18040      For  HB 2604                                     Neavel     MD,
# 18041      For  HB 2604  Association\nof Obstretics and Gynecology   Texas
# 18060      For  HB 2604              Academy\nof Family Physicians    MOD,
#
#                                                           title   org    city  \
# 24                                           Physical therapist  None    None
# 25                                                         None  None  Dallas
# 296                                 Ambulatory Medical Director  None    None
# 297                                                        None  None  Dallas
# 982    Director, Intergovernmental Relations & Policy Oversight  None    None
# 983                                                        None  None  Austin
# 5232                                                       None  None    None
# 5260                Director, Texas Veterans Leadership Program  None    None
# 5261                                                       None  None  Austin
# 5436                                                       None  None    None
# 9243                                                       None  None    None
# 10351                                        Executive Director  None    None
# 10352                                                      None  None  Austin
# 10709                                                      None  None    None
# 12269                                                      None  None    None
# 13272                                                      None  None    None
# 13273                                                      None  None    None
# 14016                                                      None  None    None
# 14017                                                      None  None    None
# 14018                                                      None  None  Austin
# 15319                                                      None  None    None
# 15354                                                      None  None    None
# 15355                                                      None  None    None
# 17042                                                      None  None    None
# 17043                                                      None  None    None
# 17073                                                      None  None    None
# 17143                                                        Dr  None    None
# 17144                                                      None  None    None
# 17145                                                      None  None  Austin
# 17548                                                      None  None    None
# 18040                                                      None  None    None
# 18041                                                      None  None    None
# 18060                                                      None  None    None
#
#       state
# 24     None
# 25       TX
# 296    None
# 297      TX
# 982    None
# 983      TX
# 5232   None
# 5260   None
# 5261     TX
# 5436   None
# 9243   None
# 10351  None
# 10352    TX
# 10709  None
# 12269  None
# 13272  None
# 13273  None
# 14016  None
# 14017  None
# 14018    TX
# 15319  None
# 15354  None
# 15355  None
# 17042  None
# 17043  None
# 17073  None
# 17143  None
# 17144  None
# 17145    TX
# 17548  None
# 18040  None
# 18041  None
# 18060  None

# %%
# df[df['bill'] == "HB 2"]

# %%
# Looking at a random sample

df.sample(n = 40)
# Out:
#                                                                                                                     raw  \
# 16692                                                                Allred,\nAnna (Texas Society of Anesthesiologists)
# 1041                                                                   White,\nMichael (Texas Construction Association)
# 15185                                                                                         Parkinson,\nThomas (Self)
# 7323                                                       Suhm,\nVic (Self; Tarrant Regional Transportation Coalition)
# 23304                                                      Wiggins,\nMark (Association of Texas Professional Educators)
# 17153                            Francis,\nWill    (National Association of Social Workers - Texas Chapter), Austin, TX
# 11142                                                                        Travis,\nClayton (Texas Pediatric Society)
# 20413                                                 Conkwright,\nJim (Prairielands Groundwater Conservation District)
# 5537                                                                 Green,\nJoseph (Travis County Commissioners Court)
# 9796                                                     Sanford,\nTiana (Montgomery County District Attorney's Office)
# 6021                                                                                              Zuniga,\nAllie (Self)
# 4489                                                              Thompson,\nRodney (Self; Texas Probation Association)
# 19443                                                                              Price,\nBob (Texas Deer Association)
# 11594                                                                                Vaughan,\nDee (Self; Moore County)
# 19425                       Kromrei,\nLiz   Director of Services  (Dept of Family and Protective Services), Austin,\nTX
# 8967               Hemphill,\nColeman    (Self- World Wide Notary - Written by American Assoc. of Notaries),\nBrady, TX
# 22280                                          Cates,\nAndrew   General Counsel  (Texas Nurses Association), Austin, TX
# 23873                                                                                           Alleman,\nMonica (Self)
# 20385                                                 Lewis,\nKathryn   Attorney  (Disability Rights Texas), Austin, TX
# 25927                                                                      Alexander,\nTroy (Texas Medical Association)
# 11339                                                               Fickel,\nAnn (Texas Classroom Teachers Association)
# 22583                                                                                           Taylor,\nLatosha (Self)
# 23347                                                                 Williams,\nKortney (Self; Ector County DA and CA)
# 15652                                                                                               Seago,\nJohn (Self)
# 9918                                                                 McDonald,\nCraig (Self; Texans for public justice)
# 23774  Nichols,\nColby (Texas Rural Education Association; Instructional Materials Coordinators' Association\nof Texas)
# 14993                                                                                  Hays,\nSusan (GB Sciences, Inc.)
# 4717                                                       Hudman,\nJoyce (Self; County and District Clers Association)
# 8236                                                                         Martinez,\nMonica (Texas Education Agency)
# 19070                                                                                        Arnold,\nEllen (Texas PTA)
# 557                                                                                                Dolan,\nMoira (Self)
# 25072                                                                   Martin,\nAmanda (Texas Association of Business)
# 17745                                   Zurek,\nMatt (Texas Department of Insurance, Division of Workers' Compnesation)
# 427                                                                                     Lacefield\nlewis, Lauren (Hhsc)
# 20190                                                             Scaman,\nRicky (Self; Sheriff's Association of Texas)
# 21977                                                                                               Adams,\nKyle (Self)
# 12144                 Francis,\nBrian   Executive Director  (Texas Department of Licensing and Regulation), Austin,\nTX
# 22655                                                               Guzman,\nMonica (Texas Court Reporters Association)
# 18358                                                                           Briscoe,\nRick (Self; Open Carry Texas)
# 11734                                               Spilman,\nAnnie (National Federation of Independent Business/Texas)
#
#       position     bill              last    first                 title  \
# 16692      For  HB 2397            Allred     Anna                  None
# 1041       For    HB 22             White  Michael                  None
# 15185      For  HB 2115         Parkinson   Thomas                  None
# 7323       For   HB 890              Suhm      Vic                  None
# 23304      For  HB 3526           Wiggins     Mark                  None
# 17153      For  HB 2466           Francis     Will
# 11142      For  HB 1549            Travis  Clayton                  None
# 20413      For  HB 3025        Conkwright      Jim                  None
# 5537   Against   HB 532             Green   Joseph                  None
# 9796       For  HB 1357           Sanford    Tiana                  None
# 6021       For   HB 610            Zuniga    Allie                  None
# 4489       For   HB 387          Thompson   Rodney                  None
# 19443      For  HB 2855             Price      Bob                  None
# 11594      For  HB 1603           Vaughan      Dee                  None
# 19425       On  HB 2848           Kromrei      Liz  Director of Services
# 8967   Against  HB 1217          Hemphill  Coleman
# 22280      For  HB 3296             Cates   Andrew       General Counsel
# 23873      For  HB 3682           Alleman   Monica                  None
# 20385      For  HB 3019             Lewis  Kathryn              Attorney
# 25927      For  HB 4237         Alexander     Troy                  None
# 11339      For  HB 1569            Fickel      Ann                  None
# 22583      For  HB 3353            Taylor  Latosha                  None
# 23347      For  HB 3539          Williams  Kortney                  None
# 15652      For  HB 2222             Seago     John                  None
# 9918       For  HB 1378          McDonald    Craig                  None
# 23774  Against  HB 3635           Nichols    Colby                  None
# 14993      For  HB 2107              Hays    Susan                  None
# 4717       For   HB 431            Hudman    Joyce                  None
# 8236        On  HB 1076          Martinez   Monica                  None
# 19070      For  HB 2782            Arnold    Ellen                  None
# 557    Against    HB 11             Dolan    Moira                  None
# 25072      For  HB 3954            Martin   Amanda                  None
# 17745       On  HB 2546             Zurek     Matt                  None
# 427         On    HB 10  Lacefield\nlewis   Lauren                  None
# 20190      For  HB 2991            Scaman    Ricky                  None
# 21977      For  HB 3238             Adams     Kyle                  None
# 12144       On  HB 1698           Francis    Brian    Executive Director
# 22655      For  HB 3374            Guzman   Monica                  None
# 18358  Against  HB 2655           Briscoe     Rick                  None
# 11734      For  HB 1635           Spilman    Annie                  None
#
#                                                                                                   org  \
# 16692                                                              Texas Society of Anesthesiologists
# 1041                                                                   Texas Construction Association
# 15185                                                                                            Self
# 7323                                                  Self; Tarrant Regional Transportation Coalition
# 23304                                                     Association of Texas Professional Educators
# 17153                                          National Association of Social Workers - Texas Chapter
# 11142                                                                         Texas Pediatric Society
# 20413                                                  Prairielands Groundwater Conservation District
# 5537                                                                Travis County Commissioners Court
# 9796                                                     Montgomery County District Attorney's Office
# 6021                                                                                             Self
# 4489                                                                Self; Texas Probation Association
# 19443                                                                          Texas Deer Association
# 11594                                                                              Self; Moore County
# 19425                                                          Dept of Family and Protective Services
# 8967                                 Self- World Wide Notary - Written by American Assoc. of Notaries
# 22280                                                                        Texas Nurses Association
# 23873                                                                                            Self
# 20385                                                                         Disability Rights Texas
# 25927                                                                       Texas Medical Association
# 11339                                                            Texas Classroom Teachers Association
# 22583                                                                                            Self
# 23347                                                                    Self; Ector County DA and CA
# 15652                                                                                            Self
# 9918                                                                  Self; Texans for public justice
# 23774  Texas Rural Education Association; Instructional Materials Coordinators' Association\nof Texas
# 14993                                                                               GB Sciences, Inc.
# 4717                                                      Self; County and District Clers Association
# 8236                                                                           Texas Education Agency
# 19070                                                                                       Texas PTA
# 557                                                                                              Self
# 25072                                                                   Texas Association of Business
# 17745                                Texas Department of Insurance, Division of Workers' Compnesation
# 427                                                                                              Hhsc
# 20190                                                            Self; Sheriff's Association of Texas
# 21977                                                                                            Self
# 12144                                                    Texas Department of Licensing and Regulation
# 22655                                                               Texas Court Reporters Association
# 18358                                                                          Self; Open Carry Texas
# 11734                                               National Federation of Independent Business/Texas
#
#          city state
# 16692    None  None
# 1041     None  None
# 15185    None  None
# 7323     None  None
# 23304    None  None
# 17153  Austin    TX
# 11142    None  None
# 20413    None  None
# 5537     None  None
# 9796     None  None
# 6021     None  None
# 4489     None  None
# 19443    None  None
# 11594    None  None
# 19425  Austin    TX
# 8967    Brady    TX
# 22280  Austin    TX
# 23873    None  None
# 20385  Austin    TX
# 25927    None  None
# 11339    None  None
# 22583    None  None
# 23347    None  None
# 15652    None  None
# 9918     None  None
# 23774    None  None
# 14993    None  None
# 4717     None  None
# 8236     None  None
# 19070    None  None
# 557      None  None
# 25072    None  None
# 17745    None  None
# 427      None  None
# 20190    None  None
# 21977    None  None
# 12144  Austin    TX
# 22655    None  None
# 18358    None  None
# 11734    None  None

# %%
def changeN(cell):
    if cell != None:
        cell = cell.replace("\n", " ")
    return cell
    
newList = [[changeN(cell) for cell in line] for line in newList]

# %%
import csv

def export(dir, witList):
    with open(dir,'w') as f:
        writer = csv.writer(f)
        writer.writerow(['FullText', 'Position', 'Bill', 'LastName', 'FirstName', 'Role', 'Organization', 'City', 'State'])
        writer.writerows(witList) # better just to include the text maybe.
    return None

houseDir = '../data/witness-lists/HouseWitness.csv'
export(houseDir, newList)

# %%
# duplicating the House process for the Senate

folderName = 'bills/85R/witlistbill/html/senate_bills/'
senateWit = extractRows(folderName)
senList = mergelines(senateWit)
senList = mergelines(senList)
for line in senList:
    line.extend(addName(line))
    line.extend(addTitle(line))
    line.extend(addOrg(line))
    line.extend(addCity(line))
senList = [[changeN(cell) for cell in line] for line in senList]

# %%
senateDir = '../data/witness-lists/SenateWitness.csv'
export(senateDir, senList)

# %%
# Just looking at a sample of the data. Maybe 95% correct.

sen = pd.DataFrame(senList, columns=list(['raw', 'position', 'bill', 'last','first','title', 'org','city','state']))
sen.sample(n = 40)
# Out:
#                                                                                                               raw  \
# 17242                                                                              Herring, Megan (First 3 Years)
# 16897      Garcia, Imelda   Director, Infectious Disease Prevention  (Dept. of State Health Services), Austin, TX
# 15876                                                                         Bostur, Jill    (Self) , Austin, TX
# 7909   Eaton, Holly   Director of Professional Development & Advocacy  (TX Classroom Teachers Assoc.), Austin, TX
# 14090                                               Bowden, Rachel    (Texas Department of Insurance), Austin, TX
# 6796                                                                        Gibson, Judson    (Self) , Austin, TX
# 4894                                                                         Dallas, James    (Self) , Austin, TX
# 14028                          Kennedy, Ted   Deputy Head Of State Governmental Affairs / AIG  (AIG), Houston, TX
# 7540                             Kimberly, Knox   SVP - Advocacy and Stakeholder Relations  (Upbring), Austin, TX
# 10045                                                                 Lovatos, Amber    (Self; TDHA), Houston, TX
# 12857                                  Ryan, Patricia   General Counsel  (Old American County Mutual), Dallas, TX
# 9501                                                                         Thompson, Jay    (Afact), Austin, TX
# 10855                                                                McKinney, Nancy Beth    (Self) , Houston, TX
# 8131                                        Hawthorne, Brian   Sheriff  (Sheriff of Chambers County), Baytown, TX
# 7545                     Olse, Katie   Executive Director  (TX Alliance of Child and Family Services), Austin, TX
# 4145                                                    Puente, Vince E.   Executive; Sr  (Self) , Fort Worth, TX
# 7639                                 Lambert, Michael    (also providing written testimony)  (Self) , Houston, TX
# 10434                       Quinzi, Patty   Legislative Counsel  (TX-American Federation of Teachers), Austin, TX
# 11940                                                                    Mattox, Christine    (Self) , Austin, TX
# 10127                                                                  Ashworth, Stephanie    (Self) , Austin, TX
# 6648                                                                Anderson, Jessica (Houston Police Department)
# 4257                                                                   Hernandez, Tony   Mr.  (Self) , Austin, TX
# 11476                                                                      Motheral, Mike    (Self) , Lubbock, TX
# 16196          Allison, Jim   General Counsel  (County Judges and Commissioners Association of Texas), Austin, TX
# 9387                           Hall, Terri   Director  (Texas TURF/Texans for Tollfree Highways), San Anotnio, TX
# 426                                    Olse, Katie   Executive Director  (TX Alliance of Child & Family Services)
# 16381                                                                          Belile, Liz    (Self) , Austin, TX
# 8332               Curimbaba, Sally Thorpe    (Self; Texas Unitarian Universalist Justice Ministry), Fulshear, TX
# 5127                                                                      Guthrie, Meghann    (Self) , Austin, TX
# 10972       Gonzalez, M.D., M.P.H., Hector F.    (also providing written testimony)  (City of Laredo), Laredo, TX
# 3680                                                              Renderosmonges, Amilcar    (Self) , Uustint, TX
# 14578                                                   Gustafson, Lindsay (Texas Classroom Teachers Association)
# 2508                                                                 Kolly, Faye   AILA  (Self; AILA), Austin, TX
# 10768                                              LeBas, James   fiscal analyst  (Rackspace Hosting), Austin, TX
# 17448                                      DeLanglo, Wayne    (San Antonio Fire Dept. Local 624), San Antonio, TX
# 4923                                                                  Delgado, Estevan   Mr.  (Self) , Austin, TX
# 14115                                         Blair, John   Ceo ogle schools  (Self; Ogle schools), Arlingtom, TX
# 784                                        Perdue, Caitlin   LBB Staff  (also providing written testimony)  (LBB)
# 11103                                                                           Veterans Association), Belton, TX
# 586                 Camacho, Raul   Firearm Instructor / Safety Measures  (Firearm Training Industry), Austin, TX
#
#       position     bill            last         first  \
# 17242      For  SB 1839         Herring         Megan
# 16897       On  SB 1683          Garcia        Imelda
# 15876  Against  SB 1443          Bostur          Jill
# 7909       For   SB 160           Eaton         Holly
# 14090       On  SB 1076          Bowden        Rachel
# 6796   Against    SB 13          Gibson        Judson
# 4894   Against     SB 6          Dallas         James
# 14028      For  SB 1071         Kennedy           Ted
# 7540       For    SB 74        Kimberly          Knox
# 10045      For   SB 430         Lovatos         Amber
# 12857      For   SB 878            Ryan      Patricia
# 9501        On   SB 408        Thompson           Jay
# 10855      For   SB 547        McKinney    Nancy Beth
# 8131       For   SB 227       Hawthorne         Brian
# 7545       For    SB 74            Olse         Katie
# 4145       For     SB 6          Puente         Vince
# 7639        On    SB 83         Lambert       Michael
# 10434      For   SB 489          Quinzi         Patty
# 11940      For   SB 715          Mattox     Christine
# 10127  Against   SB 451        Ashworth     Stephanie
# 6648       For    SB 12        Anderson       Jessica
# 4257   Against     SB 6       Hernandez          Tony
# 11476  Against   SB 640        Motheral          Mike
# 16196  Against  SB 1524         Allison           Jim
# 9387       For   SB 385            Hall         Terri
# 426        For     SB 1            Olse         Katie
# 16381      For  SB 1565          Belile           Liz
# 8332   Against   SB 258       Curimbaba  Sally Thorpe
# 5127   Against     SB 6         Guthrie       Meghann
# 10972      For   SB 570        Gonzalez         M.D.,
# 3680   Against     SB 4  Renderosmonges       Amilcar
# 14578      For  SB 1153       Gustafson       Lindsay
# 2508   Against     SB 4           Kolly          Faye
# 10768      For   SB 532           LeBas         James
# 17448      For  SB 1878        DeLanglo         Wayne
# 4923   Against     SB 6         Delgado       Estevan
# 14115      For  SB 1088           Blair          John
# 784         On     SB 1          Perdue       Caitlin
# 11103      For   SB 588            None          None
# 586         On     SB 1         Camacho          Raul
#
#                                                  title  \
# 17242                                             None
# 16897          Director, Infectious Disease Prevention
# 15876
# 7909   Director of Professional Development & Advocacy
# 14090
# 6796
# 4894
# 14028  Deputy Head Of State Governmental Affairs / AIG
# 7540          SVP - Advocacy and Stakeholder Relations
# 10045
# 12857                                  General Counsel
# 9501
# 10855
# 8131                                           Sheriff
# 7545                                Executive Director
# 4145                                E.   Executive; Sr
# 7639
# 10434                              Legislative Counsel
# 11940
# 10127
# 6648                                              None
# 4257                                               Mr.
# 11476
# 16196                                  General Counsel
# 9387                                          Director
# 426                                 Executive Director
# 16381
# 8332
# 5127
# 10972                                               F.
# 3680
# 14578                                             None
# 2508                                              AILA
# 10768                                   fiscal analyst
# 17448
# 4923                                               Mr.
# 14115                                 Ceo ogle schools
# 784                                          LBB Staff
# 11103                                             None
# 586               Firearm Instructor / Safety Measures
#
#                                                         org         city state
# 17242                                         First 3 Years         None  None
# 16897                        Dept. of State Health Services       Austin    TX
# 15876                                                  Self       Austin    TX
# 7909                           TX Classroom Teachers Assoc.       Austin    TX
# 14090                         Texas Department of Insurance       Austin    TX
# 6796                                                   Self       Austin    TX
# 4894                                                   Self       Austin    TX
# 14028                                                   AIG      Houston    TX
# 7540                                                Upbring       Austin    TX
# 10045                                            Self; TDHA      Houston    TX
# 12857                            Old American County Mutual       Dallas    TX
# 9501                                                  Afact       Austin    TX
# 10855                                                  Self      Houston    TX
# 8131                             Sheriff of Chambers County      Baytown    TX
# 7545               TX Alliance of Child and Family Services       Austin    TX
# 4145                                                   Self   Fort Worth    TX
# 7639                                                   Self      Houston    TX
# 10434                    TX-American Federation of Teachers       Austin    TX
# 11940                                                  Self       Austin    TX
# 10127                                                  Self       Austin    TX
# 6648                              Houston Police Department         None  None
# 4257                                                   Self       Austin    TX
# 11476                                                  Self      Lubbock    TX
# 16196  County Judges and Commissioners Association of Texas       Austin    TX
# 9387                Texas TURF/Texans for Tollfree Highways  San Anotnio    TX
# 426                  TX Alliance of Child & Family Services         None  None
# 16381                                                  Self       Austin    TX
# 8332    Self; Texas Unitarian Universalist Justice Ministry     Fulshear    TX
# 5127                                                   Self       Austin    TX
# 10972                                        City of Laredo       Laredo    TX
# 3680                                                   Self      Uustint    TX
# 14578                  Texas Classroom Teachers Association         None  None
# 2508                                             Self; AILA       Austin    TX
# 10768                                     Rackspace Hosting       Austin    TX
# 17448                      San Antonio Fire Dept. Local 624  San Antonio    TX
# 4923                                                   Self       Austin    TX
# 14115                                    Self; Ogle schools    Arlingtom    TX
# 784                                                     LBB         None  None
# 11103                                                  None       Belton    TX
# 586                               Firearm Training Industry       Austin    TX

# %%
sen.describe()
# Out:
#                                                raw position   bill   last  \
# count                                        18899    18899  18899  18485
# unique                                       13439        3    978   5498
# top     Banks, Yannis    (Texas NAACP), Austin, TX      For   SB 4  Smith
# freq                                            34     8116   2358    184
#
#         first  title    org    city  state
# count   18453  16724  18745   15811  15811
# unique   2668   3265   4974     815     34
# top      John          Self  Austin     TX
# freq      307   7289   6119    9378  15703
