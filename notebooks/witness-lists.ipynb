# %%
# The purpose of this notebook is to get a CSV of tabular data based on the witness lists.

# I used wget to collect ftp.legis.state.tx.us/bills/85R/witlistbill/html/
# and put them all together in a directory called '/bills/85R/witlistbill/html/'
# These files are not being stored in the github repo because they're too big.

# The published lists are in HTML exported from Microsoft Word, so the markup reflects 
# intended page layout rather than content.

# %%
# %%bash
# python -V
# Out:
# Python 3.6.1 :: Continuum Analytics, Inc.

# %%
import bs4
from bs4 import BeautifulSoup
bs4.__version__
# Out:
# '4.6.0'

# %%
import pandas as pd
pd.__version__
# Out:
# '0.20.3'

# %%
import re
endWithState = re.compile(r'[^\(](AL|AK|AS|AZ|AR|CA|CO|CT|DE|DC|FM|FL|GA|GU|HI|ID|IL|IN|IA|KS|KY|LA|ME|MH|MD|MA|MI|MN|MS|MO|MT|NE|NV|NH|NJ|NM|NY|NC|ND|MP|OH|OK|OR|PW|PA|PR|RI|SC|SD|TN|TX|Texas|UT|VT|VI|VA|WA|WV|WI|WY)\n?$')

# %%
def addName(line):
    """
    Takes in a string of text representing a line from a witness list file and, if it's able to identify
    the witness's name, returns a list containing a string for the last name and a string for the
    first name. The list contains "None" values if no name is found, or one string and one None if only
    a surname is found.
    """
    
    flags = [re.IGNORECASE, re.DOTALL]
    regexes = [r"^((?:[\w\'\-]+\s)*[\w\'\-]+),\n((?:\w+\s)*\w+)\xa0\xa0 ", 
              r"^((?:[\w\'\-]+\s)*[\w\'\-]+),\n((?:\w+\s)*\w+)\s+\(", 
              r"^((?:[\w\'\-]+\s)*[\w\'\-]+),[\n\s]+((?:[A-Z]\.)+)\s\s",
              r'^((?:\w+\s)*\w+),\s+([^\(\s]+) ', 
              r'^((?:\w+\s)*\w+),\s+((?:\w+\s)*\w+)  '] # third one for initials as first name
    partial = r'^(\w+)\s+\n\('  # Matches where someone put just a surname
    for f in flags:
        for r in regexes:
            nameRe = re.compile(r, f)
            match = re.search(nameRe, line)
            if match:
                return [match.group(1).strip(), match.group(2).strip()]
    
    # A separate case for the partial match
    nameRe = re.compile(partial)
    if re.search(nameRe, line):
        match = re.search(nameRe, line)
        return [match.group(1).strip(), None]
    
    # And a third case to leave the fields blank
    return [None, None]

def addTitle(line):
    """
    Takes in a string of text representing a line from a witness list file and, if it's able to identify
    the witness's job title, returns it as a string. Returns None otherwise.
    """
    
    regexes = [r',\s(?:(?:\w+\s)*\w+)\s+(.+)\s*\(also providing', r',\s(?:(?:\w+\s)*\w+)\s+(.+)\s*\(',
               '^(?:(?:\w+\s)*\w+),\s+(?:(?:\w+\s)*\w+)\s\s+(.+)\(also providing',
               '^(?:(?:\w+\s)*\w+),\s+(?:(?:\w+\s)*\w+)\s\s+(.+)\('
              #  r'^.+,\n.+\s+(.+)\s+\(also providing', r'^.+,\n.+\s+(.+)\s+\(',
              # ',\n?.+\xa0\xa0 ((?:\w+\s)*\w+)\s+(\(also providing written testimony\))?\s+\('
              ]
    for r in regexes:
        titleRe = re.compile(r)
        match = re.search(titleRe, line)
        if match:
            return match.group(1).strip()
    return None

def addOrg(line):
    """
    Takes in a string of text representing a line from a witness list file and, if it's able to identify
    the witness's organization, returns it as a string. Returns None otherwise.
    """
    
    flags = [re.IGNORECASE, re.DOTALL]
    regexes = [r'written testimony\)\s+\((.+)\)\s*(,|$)', 
              r'\s+\((.+)\)\s*(,|$)',]
    for f in flags:
        for r in regexes:
            orgRe = re.compile(r, f)
            match = re.search(orgRe, line)
            if match:
                return match.group(1).strip()
    return None

def addCity(line):
    """
    Takes in a string of text representing a line from a witness list file and, if it's able to identify
    the witness's city and state, returns a list containing a string for the last name and a string for the
    first name. The list contains "None" values otherwise.
    """
    
    extension = []
    cityRe = re.compile(r'\)\s?,\s(.*),\s(.*)$')
    match = re.search(cityRe, line)
    if match:
        return [match.group(1).strip(), match.group(2).strip()]
    return [None, None]

# %%
# I haven't made a corresponding function for Senate bills. Instead I
# reused this same function, which means the Senate data probably has
# more errors.

def HBWitness(witnessList):
    """
    Input is an HTML file from the Texas Legislature representing a witness list. The function iterates through
    the lines of HTML and populates a list with the lines representing witnesses. Each item in the list includes
    the text of the line of HTML, the word "For" "Against" or "On" depending on which section of the list the line
    came from, and the bill number. The function return the list.
    """
    
    fp = open(witnessList, encoding = 'cp1252')
    soup = BeautifulSoup(fp.read(), "html.parser")
    
    # each printed page has a class with Wordsection plus a number
    pages = soup.select("div[class^=WordSection]") 
    
    indent = re.compile(r"^\s{30}") # whitespace should mean it's a listing, page number, or the heading "WITNESS LIST"
    forStance = re.compile(r'^\s+FOR\s?:', re.IGNORECASE) # i flag means case-insensitive
    againstStance = re.compile(r'^\s+AGAINST\s?:', re.IGNORECASE)
    onStance = re.compile(r'^\s+ON\s?:', re.IGNORECASE)

    wit = []
    stance = "For"
    for page in pages:
        witpage = []
        pp = page.select("p")
        for line in pp:
            text = line.get_text()
            if re.match(forStance, text):
                stance = "For"
            if re.match(againstStance, text):
                stance = "Against"
            if re.match(onStance, text):
                stance = "On"
            if re.match(indent, text):
                witpage.append([line.get_text(), stance])
        wit.extend(witpage[1:-1])

    bill = soup.find('span', {'style':"color:windowtext;text-decoration:none"}) # identifies the bill
    bill = bill.get_text()
    for line in wit:
        line.extend([bill.strip()])
    
    wit = [x for x in wit if x != None]
    
    return wit

# %%
def mergelines(wit):
    """
    Input is a list of lists representing lines of text in a witness list document from the Legislature. 
    This function tries to determine whether whether consecutive lines refer to the same witness and need
    to be merged into one row of data. It returns a new list of lists, with those lines merged together.
    """
    
    changed = 0    
    newList = []
    badList = []
    tooShort = re.compile("^\w+\)?,?\s?(AL|AK|AS|AZ|AR|CA|CO|CT|DE|DC|FM|FL|GA|GU|HI|ID|IL\
                        |IN|IA|KS|KY|LA|ME|MH|MD|MA|MI|MN|MS|MO|MT|NE|NV|NH|NJ|NM|NY|NC\
                        |ND|MP|OH|OK|OR|PW|PA|PR|RI|SC|SD|TN|TX|Texas|UT|VT|VI|VA|WA|WV|WI|WY)?\n?$") # line shouldn't have just one word
    for row in wit:
        row[0] = row[0].strip()
    
    for row in wit[:-1]:
        lineIndex = wit.index(row)
        
        # Lines will get merged if they pass any of the three tests. Only if not will a line be accepted.
        
        if re.search(endWithState, wit[lineIndex + 1][0]) and not re.search(endWithState, row[0]) \
        and addName(row[0]) != [None, None] and addName(wit[lineIndex + 1][0]) == [None, None]:
            newList.append([row[0] + " " + wit[lineIndex + 1][0], row[1], row[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
        
        elif re.search(tooShort, wit[lineIndex + 1][0].strip()):
            newList.append([row[0] + " " + wit[lineIndex + 1][0], row[1], row[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
            
        elif row[0].count(')') != row[0].count('(') \
        and wit[lineIndex + 1][0].count(')') != wit[lineIndex + 1][0].count('(') \
        and addName(row[0]) != [None, None] and not re.search(endWithState, row[0]):
            newList.append([row[0] + " " + wit[lineIndex + 1][0], row[1], row[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
            
        elif row[0].count(')') != row[0].count('(') \
        and wit[lineIndex + 1][0].count(')') != wit[lineIndex + 1][0].count('(') \
        and addName(row[0]) != [None, None] \
        and addName(wit[lineIndex + 1][0]) == [None,None]:
            newList.append([row[0] + " " + wit[lineIndex + 1][0], row[1], row[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
            
        else:
            newList.append(row[0:3])
    
    answer = [x for x in newList if x not in badList]
    
    return answer

# %%
import shutil, os

def extractRows(folderName):
    """
    Input is the name of a folder full of witness list files. The function extracts the lines from each file,
    attempts to merge them into lists representing rows of data referring to one witness each, and returns 
    one long list of lists.
    """
    
    houseWit = []
    for folderName, subfolders, filenames in os.walk(folderName):
        for filename in filenames:
            if filename != ".DS_Store":
                source = folderName + filename
                wit = HBWitness(source)
                # trying to rejoin entries split across lines
                new = mergelines(wit)
                new = mergelines(new) # Will doing it twice catch 3-line entries?
                houseWit.extend(new)
    return houseWit
            
folderName = 'bills/85R/witlistbill/html/house_bills/'
houseWit = extractRows(folderName)

# %%
# Adding the last six fields to each row

def extendRow(row):
    """
    Input is a list representing a row of data about a witness. The function extends the list 
    with six more items and returns the extended list.
    """
    
    row.extend(addName(row[0]))
    row.append(addTitle(row[0]))
    row.append(addOrg(row[0]))
    row.extend(addCity(row[0]))
    return row

houseRows = [extendRow(row) for row in houseWit]

# %%
houseRows[:5]
# Out:
# [['Colyandro,\nJohn (Texas Conservative Coalition)',
#   'For',
#   'HB 3081',
#   'Colyandro',
#   'John',
#   None,
#   'Texas Conservative Coalition',
#   None,
#   None],
#  ['Minick,\nStephen (Texas Asssociation of Business)',
#   'For',
#   'HB 3081',
#   'Minick',
#   'Stephen',
#   None,
#   'Texas Asssociation of Business',
#   None,
#   None],
#  ['Norcross,\nRob (Consumer service alliance of texas)',
#   'For',
#   'HB 3081',
#   'Norcross',
#   'Rob',
#   None,
#   'Consumer service alliance of texas',
#   None,
#   None],
#  ['Scurlock,\nStephen (Independent Bankers Association of Texas)',
#   'For',
#   'HB 3081',
#   'Scurlock',
#   'Stephen',
#   None,
#   'Independent Bankers Association of Texas',
#   None,
#   None],
#  ['Allmon,\nJennifer (The Texas Catholic Conference of Bishops)',
#   'Against',
#   'HB 3081',
#   'Allmon',
#   'Jennifer',
#   None,
#   'The Texas Catholic Conference of Bishops',
#   None,
#   None]]

# %%
# pandas is only used for data exploration. 
# There are definitely still errors.


pd.options.display.max_colwidth = 500


df = pd.DataFrame(houseRows, columns=list(['raw', 'position', 'bill', 'last','first','title', 'org','city','state']))

# %%
# df[df['bill'] == "HB 3025"]

# %%
# These are the lines most likely to have problems

df[pd.isnull(df['org'])]
# df.first.isnull()
# Out:
#                                                                                                 raw  \
# 1289            Neavel,\nMD, Celia (Self; Texas Pediatric Society, Texas Medical Association, Texas
# 18377      For  HB 2466                                     Neavel     MD,
# 18378      For  HB 2466  Association\nof Obstretics and Gynecology   Texas
# 18408      For  HB 2466              Academy\nof Family Physicians    MOD,
# 19741      For  HB 1908                                   Guillory   M.D.,
# 19742      For  HB 1908                         Pediatric\nSociety   Texas
#
#                              title   org    city state
# 1289                          None  None    None  None
# 1290                          None  None    None  None
# 1309                          None  None    None  None
# 2710                            Dr  None    None  None
# 2711                          None  None    None  None
# 2712                          None  None  Austin    TX
# 4004   Ambulatory Medical Director  None    None  None
# 4005                          None  None  Dallas    TX
# 8683                          None  None    None  None
# 10662                         None  None    None  None
# 10663                         None  None    None  None
# 10664                         None  None  Austin    TX
# 11637                         None  None    None  None
# 12001                         None  None    None  None
# 12504           Executive Director  None    None  None
# 12505                         None  None  Austin    TX
# 13230           Physical therapist  None    None  None
# 13231                         None  None  Dallas    TX
# 14697                         None  None    None  None
# 16589                         None  None    None  None
# 16624                         None  None    None  None
# 16625                         None  None    None  None
# 18377                         None  None    None  None
# 18378                         None  None    None  None
# 18408                         None  None    None  None
# 19741                         None  None    None  None
# 19742                         None  None    None  None

# %%
# df[df['bill'] == "HB 2"]

# %%
# Looking at a random sample

df.sample(n = 40)
# Out:
#                                                                                                                      raw  \
# 5506                                                                                             Booker,\nFrances (Self)
# 13838                                                                                        Wood,\nRobert (Comptroller)
# 8124                                                                        Santellana,\nStephen (City of Wichita Falls)
# 10793                                                                                       Sarantakes,\nKimberly (Self)
# 3428                                                                                  Embrey,\nTy    (Self) , Austin, TX
# 3519                         Kunish,\nEric (Self; National Alliance foe Mental Illness Austin, Advocacy Committee Chair)
# 2718                                                      Davis,\nDixie    (League of Women Voters of Texas), Austin, TX
# 11967                                                                Ruiz,\nDavid (Self; Retired dallas police officers)
# 12719  Esparza,\nServando   Manager of Government Affairs  (Texas Independent Producers and Royalty\nOwners), Austin, TX
# 5369                                                                              Ivic,\nMichael (Self; Misho Oyster Co)
# 7875                                                       Ingram,\nKeith (Texas Secretary of State, Elections Division)
# 10823                                                                  SCHOCH,\nALEXANDER (Railroad Commission of Texas)
# 21567                                                                           Harms,\nLynn (Childrens home of lubbock)
# 2402                                                              CHIMENE,\nGRACE (Self; Leaue of women Voters of Texas)
# 13238                                       Caplinger,\nTJ   CEO  (Pediatric Therapy - Child's Play Therapeutc Homecare)
# 633                                                                         Reyna,\nLeeland (Self; Safety Measures, llc)
# 2767                                                                         Doyle,\nMarilyn (Texas Medical Association)
# 11278                                                                  Jackson,\nTim (Self; Dallas Builders Association)
# 444                                                                                             Bachman,\nSolomon (Self)
# 16249                                   Barnett,\nPaula   Government Relations Senior Director  (BP America), Austin, TX
# 2484                                                                      Jackson,\nRoy (Texas New Mexico Power Company)
# 8040                                                                                              Britton,\nJaden (Self)
# 20696                                                                                            Ward,\nKyle (Texas PTA)
# 14243                                                                                               Meier,\nKelly (Self)
# 2452                                                                         Dunlap,\nCyndy (Texas Hospital Association)
# 21373                                                                                   Wang,\nWei (Railroad Commission)
# 21637                                                                      Hiner,\nHarrison (Texas state employees nion)
# 2484                                        None
# 8040                                        None
# 20696                                       None
# 14243                                       None
# 2452                                        None
# 21373                                       None
# 21637                                       None
# 21535                                       None
# 16259                                   Director
# 6563                                        None
# 20010                                       None
# 18892  (Foundation appraisers coalition of texas
# 18698                            General Counsel
# 14828                                       None
# 13882                                       None
# 11842                                       None
# 7805                                        None
# 14045                                       None
# 4715                                        None
# 3354                                        None
#
#                                                                                org  \
# 5506                                                                          Self
# 13838                                                                  Comptroller
# 8124                                                         City of Wichita Falls
# 10793                                                                         Self
# 3428                                                                          Self
# 3519   Self; National Alliance foe Mental Illness Austin, Advocacy Committee Chair
# 2718                                               League of Women Voters of Texas
# 11967                                         Self; Retired dallas police officers
# 12719                              Texas Independent Producers and Royalty\nOwners
# 5369                                                         Self; Misho Oyster Co
# 7875                                  Texas Secretary of State, Elections Division
# 10823                                                 Railroad Commission of Texas
# 21567                                                    Childrens home of lubbock
# 2402                                          Self; Leaue of women Voters of Texas
# 13238                         Pediatric Therapy - Child's Play Therapeutc Homecare
# 633                                                     Self; Safety Measures, llc
# 2767                                                     Texas Medical Association
# 11278                                            Self; Dallas Builders Association
# 444                                                                           Self
# 16249                                                                   BP America
# 2484                                                Texas New Mexico Power Company
# 8040                                                                          Self
# 20696                                                                    Texas PTA
# 14243                                                                         Self
# 2452                                                    Texas Hospital Association
# 21373                                                          Railroad Commission
# 21637                                                   Texas state employees nion
# 21535                                                  Texas Apartment Association
# 16259                                                                         AT&T
# 6563                                              Texas Society of Anthesiologists
# 20010                                                Texas Association of Business
# 18892                              Foundation appraisers coalition of texas (FACT)
# 18698                                                Texas State Board of Pharmacy
# 14828                                                      Disability Rights Texas
# 13882                                                       Abolish Abortion Texas
# 11842                                              Dallas retired  police officers
# 7805                                                                          Self
# 14045                                                         United Ways of Texas
# 4715                                            Texas Conference of Urban Counties
# 3354                                        Texas Association of Community Schools
#
#          city state
# 5506     None  None
# 13838    None  None
# 8124     None  None
# 10793    None  None
# 3428   Austin    TX
# 3519     None  None
# 2718   Austin    TX
# 11967    None  None
# 12719  Austin    TX
# 5369     None  None
# 7875     None  None
# 10823    None  None
# 21567    None  None
# 2402     None  None
# 13238    None  None
# 633      None  None
# 2767     None  None
# 11278    None  None
# 444      None  None
# 16249  Austin    TX
# 2484     None  None
# 8040     None  None
# 20696    None  None
# 14243    None  None
# 2452     None  None
# 21373    None  None
# 21637    None  None
# 21535    None  None
# 16259  Austin    TX
# 6563     None  None
# 20010    None  None
# 18892    None  None
# 18698  Austin    TX
# 14828    None  None
# 13882    None  None
# 11842    None  None
# 7805     None  None
# 14045    None  None
# 4715     None  None
# 3354     None  None

# %%
def changeN(cell):
    if cell != None:
        cell = cell.replace("\n", " ")
    return cell
    
houseRows = [[changeN(cell) for cell in line] for line in houseRows]

# %%
import csv

def export(dir, witList):
    with open(dir,'w') as f:
        writer = csv.writer(f)
        writer.writerow(['FullText', 'Position', 'Bill', 'LastName', 'FirstName', 'Role', 'Organization', 'City', 'State'])
        writer.writerows(witList) # better just to include the FullText field.
    return None

houseDir = '../data/witness-lists/HouseWitness.csv'
export(houseDir, houseRows)

# %%
# duplicating the House process for the Senate

folderName = 'bills/85R/witlistbill/html/senate_bills/'
senateWit = extractRows(folderName)
senList = [extendRow(row) for row in senateWit]
senList = [[changeN(cell) for cell in row] for row in senList]

# %%
senateDir = '../data/witness-lists/SenateWitness.csv'
export(senateDir, senList)

# %%
# Just looking at a sample of the data. Maybe 95% correct.

sen = pd.DataFrame(senList, columns=list(['raw', 'position', 'bill', 'last','first','title', 'org','city','state']))
sen.sample(n = 40)
# Out:
#                                                                                                                                                raw  \
# 2216                                                                                       Mathews, Miles    (Voya Financial Services), Austin, TX
# 1947                                                                                    Carr, Snapper   Attorney  (City of Georgetown), Austin, TX
# 4516                                                                                                     Valenzuela, Bailey    (Self) , Austin, TX
# 1848                                                  Huss, Jonathan   Interim Associate Commissioner  (Dept of State Health Services), Austin, TX
# 4030                                                                                                            Lowe, Emily    (Self) , Austin, TX
# 10401                                                              Mendez, Mark   Assistant  County Administrator  (Tarrant County), Ft. Worth, TX
# 13337                                                                                                  Castillon, Oscar    (Self) , Round Rock, TX
# 14251                                                            Hiner, Harrison   Legislative director  (Texas state employees union), Austin, TX
# 7543                                                              Allen, Ray   Government Affairs  (Texas Probation Association), Marble Falls, TX
# 5531                                                                                                                          McCain, Brent (Self)
# 8132                                                                                                     Gonzalez, Leah (Healthy Futures of Texas)
# 3795                                                                                                       Griffith, Carrie    (Self) , Austin, TX
# 6282                                                                                                          Puente, Jaime    (Self) , Austin, TX
# 14995                                                                                          Colon, Elena    (Self; Casa Marianella), Austin, TX
# 7635                                                                                                         Smith, Sheila    (Self) , Leander, TX
# 14428  Kerker, Juliana (American Congress if Obstetricians and Gynecologists-Texas District, Texas Association of Obstetricians and Gynecologists)
# 16994                                                                                              Moore, Matt (Children's Health System of Texas)
# 2089                                                   Lawson, John E.   Executive Director  (Houston Police Officers Pension System), Houston, TX
# 12627                                                               Terrell, James   Government Affairs  (Select Milk Producers, Inc.), Austin, TX
# 15901                                                                                                         Smith, Karina    (Self) , Austin, TX
# 11928                                                                                    Whitlock, Jettie   Bandera ATPE  (Self) , Bandera, TX, TX
# 7437                                                               Cantu, Richard   Deputy Executive Director  (East Aldine District), Houston, TX
# 15726                                                                                                        Ponzio, Daniel    (Self) , Austin, TX
# 168                                                                                           Johnson, William Blake   Electrical Engineer  (Self)
# 13471                                                                                                    Deotte, Richard    (Self) , Southlake, TX
# 9133                                                Mendoza, Roy   Citizen-USA-Texas  (also providing written testimony)  (Self) , San Antonio, TX
# 3145                                                                      Castilla, Cindi    (Self; Dallas Eagle Forum as a Volunteer), Dallas, TX
# 5166                                                                                    Cannone, Thure    (Texas Pipeline Association), Austin, TX
# 11265                                                                                              Nally, Elizabeth   MD  (Self) , San Antonio, TX
# 4464                                                                                                       Swanson, Lisa   MD  (Self) , Dallas, TX
# 9847                                                                                                 Trainor, Trey   Attorney  (Self) , Austin, TX
# 3976                                                                                                      Lafair, Renee    (Self) , Austin, tx, TX
# 6068
# 3686                          Director
# 1568
# 14029           Director of Operations
# 15802
# 16352
# 12302
#
#                                                                                                                              org  \
# 2216                                                                                                     Voya Financial Services
# 1947                                                                                                          City of Georgetown
# 4516                                                                                                                        Self
# 1848                                                                                               Dept of State Health Services
# 4030                                                                                                                        Self
# 10401                                                                                                             Tarrant County
# 13337                                                                                                                       Self
# 14251                                                                                                Texas state employees union
# 7543                                                                                                 Texas Probation Association
# 5531                                                                                                                        Self
# 8132                                                                                                    Healthy Futures of Texas
# 3795                                                                                                                        Self
# 6282                                                                                                                        Self
# 14995                                                                                                      Self; Casa Marianella
# 7635                                                                                                                        Self
# 14428  American Congress if Obstetricians and Gynecologists-Texas District, Texas Association of Obstetricians and Gynecologists
# 16994                                                                                          Children's Health System of Texas
# 2089                                                                                      Houston Police Officers Pension System
# 12627                                                                                                Select Milk Producers, Inc.
# 15901                                                                                                                       Self
# 11928                                                                                                                       Self
# 7437                                                                                                        East Aldine District
# 15726                                                                                                                       Self
# 168                                                                                                                         Self
# 13471                                                                                                                       Self
# 9133                                                                                                                        Self
# 3145                                                                                     Self; Dallas Eagle Forum as a Volunteer
# 5166                                                                                                  Texas Pipeline Association
# 11265                                                                                                                       Self
# 4464                                                                                                                        Self
# 9847                                                                                                                        Self
# 3976                                                                                                                        Self
# 2308                                                                              Texas Association of School Business Officials
# 6068                                                                                   Texas Association for Bilingual Education
# 3686                                                                                          Texas Association of School Boards
# 1568                                                                                                        Nationwide Insurance
# 14029                                                                                                   Hill Country Youth Ranch
# 15802                                                                                                                       Self
# 16352                                                                                           Mayors's Office, City of Houston
# 12302                                                                                                     Texas Border Coalition
#
#                city state
# 2216         Austin    TX
# 1947         Austin    TX
# 4516         Austin    TX
# 1848         Austin    TX
# 4030         Austin    TX
# 10401     Ft. Worth    TX
# 13337    Round Rock    TX
# 14251        Austin    TX
# 7543   Marble Falls    TX
# 5531           None  None
# 8132           None  None
# 3795         Austin    TX
# 6282         Austin    TX
# 14995        Austin    TX
# 7635        Leander    TX
# 14428          None  None
# 16994          None  None
# 2089        Houston    TX
# 12627        Austin    TX
# 15901        Austin    TX
# 11928   Bandera, TX    TX
# 7437        Houston    TX
# 15726        Austin    TX
# 168            None  None
# 13471     Southlake    TX
# 9133    San Antonio    TX
# 3145         Dallas    TX
# 5166         Austin    TX
# 11265   San Antonio    TX
# 4464         Dallas    TX
# 9847         Austin    TX
# 3976     Austin, tx    TX
# 2308         Austin    TX
# 6068    San Antonio    TX
# 3686        El Paso    TX
# 1568         Austin    TX
# 14029        Ingram    TX
# 15802        Austin    TX
# 16352       Houston    TX
# 12302        Austin    TX

# %%
sen.describe()
# Out:
#                                                raw position   bill   last  \
# count                                        17035    17035  17035  16641
# unique                                       12500        3    827   5304
# top     Banks, Yannis    (Texas NAACP), Austin, TX  Against   SB 4  Smith
# freq                                            34     7825   2354    154
#
#         first  title    org    city  state
# count   16610  15141  16883   14267  14267
# unique   2607   3014   4623     799     33
# top      John          Self  Austin     TX
# freq      278   6904   5990    8272  14165
