# %%
# I used wget to collect ftp.legis.state.tx.us/bills/85R/witlistbill/html/senate_bills/
# and put them all together in a directory called '/bills/85R/witlistbill/html/senate_bills/'

from bs4 import BeautifulSoup
import re

# %%
endWithState = re.compile(r'[^\(](AL|AK|AS|AZ|AR|CA|CO|CT|DE|DC|FM|FL|GA|GU|HI|ID|IL|IN|IA|KS|KY|LA|ME|MH|MD|MA|MI|MN|MS|MO|MT|NE|NV|NH|NJ|NM|NY|NC|ND|MP|OH|OK|OR|PW|PA|PR|RI|SC|SD|TN|TX|Texas|UT|VT|VI|VA|WA|WV|WI|WY)\n?$')

# %%
def addName(line):
    flags = [re.IGNORECASE, re.DOTALL]
    regexes = [r'^((?:\w+\s)*\w+),\n((?:\w+\s)*\w+)\xa0\xa0 ', r'^((?:\w+\s)*\w+),\n((?:\w+\s)*\w+)\s+\(', 
              r'^((?:\w+\s)*\w+),[\n\s]+((?:[A-Z]\.)+)\s\s',
              r'^((?:\w+\s)*\w+),\s+([^\(]+) ', 
              r'^((?:\w+\s)*\w+),\s+((?:\w+\s)*\w+)  '] # second one for initials as first name
    partial = r'^(\w+)\s+\n\('  # Matches where someone put just a surname
    for f in flags:
        for r in regexes:
            nameRe = re.compile(r, f)
            match = re.search(nameRe, line[0])
            if match:
                extension = [match.group(1).strip(), match.group(2).strip()]
                return extension
    
    # A separate case for the partial match
    nameRe = re.compile(partial)
    if re.search(nameRe, line[0]):
        match = re.search(nameRe, line[0])
        extension = [match.group(1).strip(), None]
        return extension
    
    # And a third case to leave the fields blank
    extension = [None, None]
    return extension

def addTitle(line):
    regexes = [r',\s(?:(?:\w+\s)*\w+)\s+(.+)\s*\(also providing', r',\s(?:(?:\w+\s)*\w+)\s+(.+)\s*\(',
               '^(?:(?:\w+\s)*\w+),\s+(?:(?:\w+\s)*\w+)\s\s+(.+)\(also providing',
               '^(?:(?:\w+\s)*\w+),\s+(?:(?:\w+\s)*\w+)\s\s+(.+)\('
              #  r'^.+,\n.+\s+(.+)\s+\(also providing', r'^.+,\n.+\s+(.+)\s+\(',
              # ',\n?.+\xa0\xa0 ((?:\w+\s)*\w+)\s+(\(also providing written testimony\))?\s+\('
              ]
    for r in regexes:
        titleRe = re.compile(r)
        match = re.search(titleRe, line[0])
        if match:
            extension = [match.group(1).strip()]
            return extension
    extension = [None]
    return extension

def addOrg(line):
    flags = [re.IGNORECASE, re.DOTALL]
    regexes = [r'written testimony\)\s+\((.+)\)\s*(,|$)', 
              r'\s+\((.+)\)\s*(,|$)',]
    for f in flags:
        for r in regexes:
            orgRe = re.compile(r, f)
            match = re.search(orgRe, line[0])
            if match:
                extension = [match.group(1).strip()]
                return extension
    extension = [None]
    return extension

def addCity(line):
    extension = [None, None]
    cityRe = re.compile(r'\)\s?,\s(.*),\s(.*)$')
    match = re.search(cityRe, line[0])
    if match:
        extension = [match.group(1).strip(), match.group(2).strip()]
    return extension

addOrg(["Parks,\nUrsula (Legislative Budget Board)","HB 2","For"])
# Out:
# ['Legislative Budget Board']

# %%
# I haven't made a corresponding function for Senate bills. Instead I
# used this same function, which means the Senate data probably has
# more errors.

def HBWitness(witnessList):
    fp = open(witnessList, encoding = 'cp1252')
    soup = BeautifulSoup(fp.read(), "html.parser")
    
    # each printed page has a class with Wordsection plus a number
    pages = soup.select("div[class^=WordSection]") 
    
    indent = re.compile(r"^\s{30}") # whitespace should mean it's a listing, page number, or the heading "WITNESS LIST"
    forStance = re.compile(r'^\s+FOR\s?:', re.IGNORECASE) # i flag means case-insensitive
    againstStance = re.compile(r'^\s+AGAINST\s?:', re.IGNORECASE)
    onStance = re.compile(r'^\s+ON\s?:', re.IGNORECASE)

    wit = []
    stance = "For"
    for page in pages:
        witpage = []
        pp = page.select("p")
        for line in pp:
            text = line.get_text()
            if re.match(forStance, text):
                stance = "For"
            if re.match(againstStance, text):
                stance = "Against"
            if re.match(onStance, text):
                stance = "On"
            if re.match(indent, text):
                witpage.append([line.get_text(), stance])
        wit.extend(witpage[1:-1])

    bill = soup.find('span', {'style':"color:windowtext;text-decoration:none"}) # identifies the bill
    bill = bill.get_text()
    for line in wit:
        line.extend([bill.strip()])
    
    wit = [x for x in wit if x != None]
    
    return wit

# wit = HBWitness('bills/85R/witlistbill/html/house_bills/HB00002S.HTM')
# print(wit)

# %%
def mergelines(wit):
    changed = 0    
    newList = []
    badList = []
    tooShort = re.compile("^\w+,?\s?(AL|AK|AS|AZ|AR|CA|CO|CT|DE|DC|FM|FL|GA|GU|HI|ID|IL\
                        |IN|IA|KS|KY|LA|ME|MH|MD|MA|MI|MN|MS|MO|MT|NE|NV|NH|NJ|NM|NY|NC\
                        |ND|MP|OH|OK|OR|PW|PA|PR|RI|SC|SD|TN|TX|Texas|UT|VT|VI|VA|WA|WV|WI|WY)?\n?$") # line shouldn't have just one word
    for line in wit:
        line[0] = line[0].strip()
    
    for line in wit[:-1]:
        lineIndex = wit.index(line)
        
        # Lines will get merged if they pass any of the three tests. Only if not will a line be accepted.
        
        if re.search(endWithState, wit[lineIndex + 1][0]) and not re.search(endWithState, line[0]) \
        and addName(line) != [None, None] and addName(wit[lineIndex + 1]) == [None, None]:
            newList.append([line[0] + " " + wit[lineIndex + 1][0], line[1], line[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
        
        elif re.search(tooShort, wit[lineIndex + 1][0].strip()):
            newList.append([line[0] + " " + wit[lineIndex + 1][0], line[1], line[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
            
        elif line[0].count(')') != line[0].count('(') \
        and wit[lineIndex + 1][0].count(')') != wit[lineIndex + 1][0].count('(') \
        and addName(line) != [None, None] and not re.search(endWithState, line[0]):
            newList.append([line[0] + " " + wit[lineIndex + 1][0], line[1], line[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
            
        elif line[0].count(')') != line[0].count('(') \
        and wit[lineIndex + 1][0].count(')') != wit[lineIndex + 1][0].count('(') \
        and addName(line) != [None, None] \
        and addName(wit[lineIndex + 1]) == [None,None]:
            newList.append([line[0] + " " + wit[lineIndex + 1][0], line[1], line[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
            
        else:
            newList.append(line[0:3])
    
    answer = [x for x in newList if x not in badList]
    
    return answer

# %%
import shutil, os

def extractRows(folderName):
    
    houseWit = []
    for folderName, subfolders, filenames in os.walk(folderName):
        for filename in filenames:
            if filename != ".DS_Store":
                source = folderName + filename
                wit = HBWitness(source)
                # print(str(changed) + " lines changed.")
                houseWit.extend(wit)
    return houseWit
            
folderName = 'bills/85R/witlistbill/html/house_bills/'
houseWit = extractRows(folderName)

# %%
houseWit[:5]
# Out:
# [['\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Parks,\nUrsula (Legislative Budget Board)',
#   'On',
#   'HB 2'],
#  ['\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Pulver,\nWayne (Texas Legislative Budget Board)',
#   'On',
#   'HB 2'],
#  ['\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Rodell,\nLeora (Legislative Budget Board)',
#   'On',
#   'HB 2'],
#  ['\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Ashley,\nPhillip (Comptroller)',
#   'On',
#   'HB 2'],
#  ['\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 Borgstedte,\nAmy (Legislative Budget Board)',
#   'On',
#   'HB 2']]

# %%
# trying to rejoin entries split across lines
newList = mergelines(houseWit)


# check HB 51 Shepperd,\nJohn

# %%
newList = mergelines(newList) # Will doing it twice catch 3-line entries?

# %%
for line in newList:
    line.extend(addName(line))
    line.extend(addTitle(line))
    line.extend(addOrg(line))
    line.extend(addCity(line))

# %%
# pandas is only used for data exploration. 
# There are definitely still errors.

import pandas as pd
pd.options.display.max_colwidth = 500


df = pd.DataFrame(newList, columns=list(['raw', 'position', 'bill', 'last','first','title', 'org','city','state']))

# %%
df[df['bill'] == "HB 3025"]
# Out:
#                                                                                                                                           raw  \
# 20415  Ellis,\nGregory (Self; Bandera County River Authority and Groundwater District,\nGonzales County\nUWCD and other clients of the firm.)
# 20416                                                            Mauk,\nDavid (Self; Bandera County River Authority and Groundwater District)
# 20417                                                                          Schlessinger,\nSarah (Texas Alliance of Groundwater Districts)
# 20418                                                                                              Landwehr,\nMartha (Texas Chemical Council)
# 20419                                                                          Adams,\nLeah (Panola County Groundwater Conservation District)
# 20420                                                                       Conkwright,\nJim (Prairielands Groundwater Conservation District)
# 20421                                                                        Embrey,\nTy (Real Edwards Conservation and Reclamation District)
# 20422                                                                                                                Escobar,\nVanessa (Self)
# 20423                                                                                         Flatten,\nCharles (Self; Hill Country Alliance)
# 20424                                                                                              Glass,\nTom (League of Independent Voters)
# 20425                                                                                                   Harward,\nHeather (Brazos Valley GCD)
# 20426                                                                                          Massingill,\nGavin (Edwards Aquifer Authority)
# 20427                                                                                                     Mullins,\nChristopher (Sierra Club)
# 20428                                                                                    Sledge,\nBrian (Upper Trinity GCD; Prairielands GCD)
# 20429                                                                                                    Turner,\nRobert (Sutton county uwcd)
# 20430                                                                                  Williams,\nC.E. (Self; Panhandle Groundwater District)
# 20431                                                                               Parham,\nLee (Texas Department of Licensing & Regulation)
# 20432           Ellis,\nGregory    (Self; Gonzales County UWCD and Bandera County River Authority and Groundwater\nDistrict), League City, TX
# 20433                                                      Conkwtight,\nJim    (Prairielands Groundwater Conservation District), Cleburne, TX
# 20434                                                   Cook,\nRobby    (Hemphill County Underground Water Conservation Districy), Austin, TX
# 20435                                                         Embrey,\nTy    (Real Edwards Conservation and Reclamation District), Austin, TX
# 20436                                                                                    Harward,\nHeather    (Brazos Valley GCD), Austin, TX
# 20437                                       Schlessinger,\nSarah   Executive Director  (Texas Alliance of Groundwater Districts), Austin,\nTX
# 24568                                                                                  Providers)
#
#       position     bill                                       last  \
# 2073       For    HB 62                                       None
# 2074       For    HB 62                             the\nAuto Club
# 2635        On   HB 122                                       None
# 4169       For   HB 351                                       None
# 5232       For   HB 490                                    Houston
# 5260        On   HB 493                                       None
# 5261        On   HB 493                                       None
# 9242        On  HB 1260                                     Austin
# 10708      For  HB 1492                                       None
# 12130      For  HB 1697                                       None
# 12269       On  HB 1724                                     Austin
# 13272      For  HB 1908                                   Guillory
# 13273      For  HB 1908                         Pediatric\nSociety
# 14016      For  HB 1974                                     Hopper
# 14017      For  HB 1974                                       None
# 14018      For  HB 1974                                       None
# 15319      For  HB 2135              Academy\nof Family Physicians
# 15354      For  HB 2135                                     Neavel
# 15355      For  HB 2135  Association\nof Obstretics and Gynecology
# 15356      For  HB 2135                                       None
# 17043      For  HB 2466                                     Neavel
# 17044      For  HB 2466  Association\nof Obstretics and Gynecology
# 17045      For  HB 2466                                       None
# 17075      For  HB 2466              Academy\nof Family Physicians
# 17145      For  HB 2466                                     Neavel
# 17146      For  HB 2466                 Texas\nMedical Asocciation
# 17147      For  HB 2466                                       None
# 17550      For  HB 2525                          Anesthesiologists
# 18042      For  HB 2604                                     Neavel
# 18043      For  HB 2604  Association\nof Obstretics and Gynecology
# 18044      For  HB 2604                                       None
# 18063      For  HB 2604              Academy\nof Family Physicians
# 18613      For  HB 2698                                       None
# 19552      For  HB 2861                                    Cassidy
# 19553      For  HB 2861                                 Texas\nRMA
# 19554      For  HB 2861                                       None
# 24143  Against  HB 3729                                       None
# 24144  Against  HB 3729                                       None
# 24567  Against  HB 3854                                       None
# 24568  Against  HB 3854                                       None
#
#                                                             first  \
# 2073                                                         None
# 2074                           and Auto Club Co. Mutual), Austin,
# 2635                                                         None
# 4169                                                         None
# 5232                                                          Tx,
# 5260                                                         None
# 5261                                                         None
# 9242                                                       Texas,
# 10708                                                        None
# 12130                                                        None
# 12269                                                      Texas,
# 13272                                         M.D., MPH, Charleta
# 13273                                         Texas Public Health
# 14016                                                       Craig
# 14017                                                        None
# 14018                                                        None
# 15319                                            MOD, TX Care for
# 15354                                                   MD, Celia
# 15355                     Texas Academy of Family Practice, March
# 15356                                                        None
# 17043                                                   MD, Celia
# 17044                     Texas Academy of Family Practice, March
# 17045                                                        None
# 17075                                            MOD, TX Care for
# 17145                                                       Celia
# 17146         Texas Academy of Family Physicians, March of Dimes,
# 17147                                                        None
# 17550                                               Texas Medical
# 18042                                                   MD, Celia
# 18043                     Texas Academy of Family Practice, March
# 18044                                                        None
# 18063                                            MOD, TX Care for
# 18613                                                        None
# 19552                                                    C. Brian
# 19553  Central Texas RMA, Grayson County RMA, Webb County-City of
# 19554                                                        None
# 24143                                                        None
# 24144                                                        None
# 24567                                                        None
# 24568                                                        None
#
#                                                  title   org    city state
# 2073                                                    None    None  None
# 2074                                              None  None  Austin    TX
# 2635                                              None  None    None  None
# 4169                                              None  None    None  None
# 5232                                              None  None    None  None
# 5260       Director, Texas Veterans Leadership Program  None    None  None
# 5261                                              None  None  Austin    TX
# 9242                                              None  None    None  None
# 10708                                             None  None    None  None
# 25                                                                             Wood,\nTrey   Budget Director  (Health and Human Services Commission), Austin, TX
# 26                                                                                          Miller,\nJeff   Policy Specialist  (Disability Rights Texas), Austin
# 27                                                                                          Tennyson,\nTerri   Administrative Staff  (Countryside Therapy Group)
# 28                                                                                                                                     Borgstedte,\nAmy    (LBB)
# 29                                                                                                                                       Pulver,\nWayne    (LBB)
# 30                                                                                                                     Caplinger,\nMelissa   SLP  (SLP industry)
# 31                                                                                  Caplinger,\nTJ   CEO  (Pediatric Therapy - Child's Play Therapeutc Homecare)
# 32                                                    Jackson,\nVictoria   Manager / Speech Pathologist  (Kids Care Pediatric Home Health Therapy),\nAddison, TX
#
#    position  bill           last                       first  \
# 0        On  HB 2          Parks                      Ursula
# 1        On  HB 2         Pulver                       Wayne
# 2        On  HB 2         Rodell                       Leora
# 3        On  HB 2         Ashley                     Phillip
# 4        On  HB 2     Borgstedte                         Amy
# 5        On  HB 2         Keyton                       Sarah
# 6        On  HB 2          Wales                     Michael
# 7        On  HB 2         Keyton                       Sarah
# 8        On  HB 2          Parks                      Ursula
# 9        On  HB 2         Pulver                       Wayne
# 10      For  HB 2         Carter                      Bobbie
# 11      For  HB 2         Castro                         Amy
# 12      For  HB 2         Hammon                      Rachel
# 13      For  HB 2     Montgomery                       Laura
# 14      For  HB 2           West                     Barbara
# 15       On  HB 2          Adams                        Josh
# 16       On  HB 2        Colbert                        Paul
# 17       On  HB 2          Mehta                      Hannah
# 18       On  HB 2          Parks                      Ursula
# 19       On  HB 2          Riley                    Jennifer
# 20       On  HB 2         Rodell                       Leora
# 21       On  HB 2          Smith                     Charles
# 22       On  HB 2       Thompson                      Dustin
# 23       On  HB 2          Trigg                    Adrienne
# 24       On  HB 2  Van\nDen Bent  Jerre   Physical therapist
# 25       On  HB 2           Wood                        Trey
# 26      For  HB 2         Miller                        Jeff
# 27      For  HB 2       Tennyson                       Terri
# 28       On  HB 2     Borgstedte                         Amy
# 29       On  HB 2         Pulver                       Wayne
# 30      For  HB 2      Caplinger                     Melissa
# 31      For  HB 2      Caplinger                          TJ
# 32       On  HB 2        Jackson                    Victoria
#
#                                                                title  \
# 0                                                               None
# 1                                                               None
# 2                                                               None
# 3                                                               None
# 4                                                               None
# 5                                                               None
# 6                                                               None
# 7                                                               None
# 8                                                               None
# 9                                                               None
# 10                                                Physical Therapist
# 11                                            Asst. Speech Pathology
# 12                    TX Association for Home Care & Hospice (TAHCH)
# 13                                            Occupational Therapist
# 14                                           Director of Marketing -
# 15  Atlas Pediatric Therapy, Small Business Owner Home Health Agency
# 16                                                        consultant
# 17                                            parent & exec director
# 18
# 19                                                           Therapy
# 20
# 21                                            Executive Commissioner
# 22                                                 Pediatric Therapy
# 23
# 24                                                Physical therapist
# 25                                                   Budget Director
# 26                                                 Policy Specialist
# 27                                              Administrative Staff
# 28
# 29
# 30                                                               SLP
# 31                                                               CEO
# 32                                      Manager / Speech Pathologist
#
#                                                                         org  \
# 0                                                  Legislative Budget Board
# 1                                            Texas Legislative Budget Board
# 2                                                  Legislative Budget Board
# 3                                                               Comptroller
# 4                                                  Legislative Budget Board
# 5                                                  Legislative Budget Board
# 6                                                  Legislative Budget Board
# 7                                                  Legislative Budget Board
# 8                                                  Legislative Budget Board
# 9                                                  Legislative Budget Board
# 10                                          Countryside Therapy Group, Inc.
# 11                                                Child's Play Home\nHealth
# 12                                                           TAHCH)  (TAHCH
# 13                                  Countryside Therapy Group & Home Health
# 14                                     Circle\nof Care -\nPediatric Therapy
# 15              Speech,\nPhysical, Occupational Therapy Industry & Families
# 16                                                              Lee College
# 17  Protect TX Fragile Kids - 1700 families\nof medically\nfragile children
# 18                                                                      LBB
# 19                                                        Sage Care Therapy
# 20                                                                      LBB
# 21                                     Health and Human Services Commission
# 22                                                         KidsCare Therapy
# 23                                                  Protect TX Fragile Kids
# 24                                                             Therapy 2000
# 25                                     Health and Human Services Commission
# 26                                                  Disability Rights Texas
# 27                                                Countryside Therapy Group
# 28                                                                      LBB
# 29                                                                      LBB
# 30                                                             SLP industry
# 31                     Pediatric Therapy - Child's Play Therapeutc Homecare
# 32                                  Kids Care Pediatric Home Health Therapy
#
#             city state
# 0           None  None
# 1           None  None
# 2           None  None
# 3           None  None
# 4           None  None
# 5           None  None
# 6           None  None
# 7           None  None
# 8           None  None
# 9           None  None
# 10   Rising Star    TX
# 11          None  None
# 12          None  None
# 13          None  None
# 14      Bulverde    TX
# 15     Arlington    TX
# 16       Houston    TX
# 17  Flower Mound    TX
# 18          None  None
# 19          None  None
# 20          None  None
# 21        Austin    TX
# 22       Addison    TX
# 23        Austin    TX
# 24        Dallas    TX
# 25        Austin    TX
# 26          None  None
# 27          None  None
# 28          None  None
# 29          None  None
# 30          None  None
# 31          None  None
# 32       Addison    TX

# %%
df.sample(n = 40)
# Out:
#                                                                                              raw  \
# 11437                                 Holt,\nLynn (Self; Texas Justice Court Judges Association)
# 18567                                      Dudensing,\nJamie (Texas Association of Health Plans)
# 16855                                        Archer,\nJimmy (Texas Department of Motor Vehicles)
# 4896                                                      Rocap,\nBlake (NARAL Pro-Choice Texas)
# 23606                                                                      Kahn,\nSuzanne (Self)
# 9736                                    Donahue,\nLaura (Self; Texas Humane Legislation Network)
# 18107                                                Mills,\nWilliam (Self; Sheriff Association)
# 6097                                 Mills,\nSarah (Texas Association for Home Care and Hospice)
# 21186                                                      Berry,\nTraci (GoodwillCentral Texas)
# 5241                                                             Sabo,\nJason (Children at Risk)
# 19980                                                                 Rubinstein,\nCarlos (Self)
# 21627                                   McGeary,\nJudith (Self; Farm and Ranch Freedom Alliance)
# 13438                                            Flores,\nRobert (Texas Citizens Action Network)
# 23110                                                            Warndof,\nDonna (Harris County)
# 15162                                                                Lara,\nRene (Texas AFL-CIO)
# 13418                                                                        Hedtke,\nAmy (Self)
# 13516                                                                   Chatelle,\nMelody (Self)
# 23639  Chiodo,\nDana   Consultant  (Computing Technology Industry Assoc. (Comp TIA)), Austin, TX
# 6489                   Singer,\nKaci   Attorney  (Texas Juvenile Justice Department), Austin, TX
# 6561                                                                     Housson,\nShannon (TEA)
# 22574                    Francis,\nWill (National Association of Social Workers - Texas Chapter)
# 7423                                                    Tagliabue,\nTom (City of Corpus Christi)
# 13516                                               None
# 23639  Consultant  (Computing Technology Industry Assoc.
# 6489                                            Attorney
# 6561                                                None
# 22574                                               None
# 7423                                                None
# 16381                                               None
# 22548                                               None
# 22259
# 683                 (National Alliance on Mental Illness
# 10611                                               None
# 10976                                               None
# 20505                                               None
# 983                                                 None
# 3405                                                None
# 24630                                               None
# 22383                                               None
# 2940                                                None
# 17515                                               None
# 6391                                                None
# 22303                                               None
# 5998                                                None
# 25947                                               None
# 9366                                                None
#
#                                                           org    city state
# 11437            Self; Texas Justice Court Judges Association    None  None
# 18567                       Texas Association of Health Plans    None  None
# 16855                      Texas Department of Motor Vehicles    None  None
# 4896                                   NARAL Pro-Choice Texas    None  None
# 23606                                                    Self    None  None
# 9736                   Self; Texas Humane Legislation Network    None  None
# 18107                               Self; Sheriff Association    None  None
# 6097              Texas Association for Home Care and Hospice    None  None
# 21186                                   GoodwillCentral Texas    None  None
# 5241                                         Children at Risk    None  None
# 19980                                                    Self    None  None
# 21627                   Self; Farm and Ranch Freedom Alliance    None  None
# 13438                           Texas Citizens Action Network    None  None
# 23110                                           Harris County    None  None
# 15162                                           Texas AFL-CIO    None  None
# 13418                                                    Self    None  None
# 13516                                                    Self    None  None
# 23639         Computing Technology Industry Assoc. (Comp TIA)  Austin    TX
# 6489                        Texas Juvenile Justice Department  Austin    TX
# 6561                                                      TEA    None  None
# 22574  National Association of Social Workers - Texas Chapter    None  None
# 7423                                   City of Corpus Christi    None  None
# 16381            Associated Builders and Contractors of Texas    None  None
# 22548                                Texas Aspires Foundation    None  None
# 22259                           Texas Association of Business  Austin    TX
# 683          National Alliance on Mental Illness (NAMI) Texas    None  None
# 10611                                                    Self    None  None
# 10976                                         City of Killeen    None  None
# 20505                                                    Self    None  None
# 983                        Stafford Municipal School District    None  None
# 3405                            Texas Association of Realtors    None  None
# 24630                                                    Self    None  None
# 22383                         Healthy Living Matters, Houston    None  None
# 2940                                     Self; Equality Texas    None  None
# 17515                          Mental health america of texas    None  None
# 6391                                      Texas Medical Board    None  None
# 22303                            Texas Conservative Coalition    None  None
# 5998        Self; Moms Demand Action for Gun Sense in America    None  None
# 25947                                 Disability Rights Texas    None  None
# 9366                       Texas Conference of Urban Counties    None  None

# %%
noText = []
for line in houseWit:
    noText.append(line[1:])

def changeN(cell):
    if cell != None:
        cell = cell.replace("\n", " ")
    return cell
    
newList = [[changeN(cell) for cell in line] for line in newList]

# %%
import csv

def export(dir, witList):
    with open(dir,'w') as f:
        writer = csv.writer(f)
        writer.writerow(['FullText', 'Position', 'Bill', 'LastName', 'FirstName', 'Role', 'Organization', 'City', 'State'])
        writer.writerows(witList) # better just to include the text maybe.
    return None

houseDir = '../data/HouseWitness.csv'
export(houseDir, newList)

# %%
# duplicating the House process for the Senate

folderName = 'bills/85R/witlistbill/html/senate_bills/'
senateWit = extractRows(folderName)
senList = mergelines(senateWit)
senList = mergelines(senList)
for line in senList:
    line.extend(addName(line))
    line.extend(addTitle(line))
    line.extend(addOrg(line))
    line.extend(addCity(line))
senList = [[changeN(cell) for cell in line] for line in senList]

# %%
senateDir = '../data/SenateWitness.csv'
export(senateDir, senList)
