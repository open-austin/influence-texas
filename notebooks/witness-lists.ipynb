# %%
# The purpose of this notebook is to get a CSV of tabular data based on the witness lists.

# I used wget to collect ftp.legis.state.tx.us/bills/85R/witlistbill/html/
# and put them all together in a directory called '/bills/85R/witlistbill/html/'
# These files are not being stored in the github repo because they're too big.

# The published lists are in HTML exported from Microsoft Word, so the markup reflects 
# intended page layout rather than content.

from bs4 import BeautifulSoup
import re

# %%
endWithState = re.compile(r'[^\(](AL|AK|AS|AZ|AR|CA|CO|CT|DE|DC|FM|FL|GA|GU|HI|ID|IL|IN|IA|KS|KY|LA|ME|MH|MD|MA|MI|MN|MS|MO|MT|NE|NV|NH|NJ|NM|NY|NC|ND|MP|OH|OK|OR|PW|PA|PR|RI|SC|SD|TN|TX|Texas|UT|VT|VI|VA|WA|WV|WI|WY)\n?$')

# %%
def addName(line):
    """
    Takes in a string of text representing a line from a witness list file and, if it's able to identify
    the witness's name, returns a list containing a string for the last name and a string for the
    first name. The list contains "None" values if no name is found, or one string and one None if only
    a surname is found.
    """
    
    flags = [re.IGNORECASE, re.DOTALL]
    regexes = [r"^((?:[\w\'\-]+\s)*[\w\'\-]+),\n((?:\w+\s)*\w+)\xa0\xa0 ", 
              r"^((?:[\w\'\-]+\s)*[\w\'\-]+),\n((?:\w+\s)*\w+)\s+\(", 
              r"^((?:[\w\'\-]+\s)*[\w\'\-]+),[\n\s]+((?:[A-Z]\.)+)\s\s",
              r'^((?:\w+\s)*\w+),\s+([^\(\s]+) ', 
              r'^((?:\w+\s)*\w+),\s+((?:\w+\s)*\w+)  '] # third one for initials as first name
    partial = r'^(\w+)\s+\n\('  # Matches where someone put just a surname
    for f in flags:
        for r in regexes:
            nameRe = re.compile(r, f)
            match = re.search(nameRe, line)
            if match:
                return [match.group(1).strip(), match.group(2).strip()]
    
    # A separate case for the partial match
    nameRe = re.compile(partial)
    if re.search(nameRe, line):
        match = re.search(nameRe, line)
        return [match.group(1).strip(), None]
    
    # And a third case to leave the fields blank
    return [None, None]

def addTitle(line):
    """
    Takes in a string of text representing a line from a witness list file and, if it's able to identify
    the witness's job title, returns it as a string. Returns None otherwise.
    """
    
    regexes = [r',\s(?:(?:\w+\s)*\w+)\s+(.+)\s*\(also providing', r',\s(?:(?:\w+\s)*\w+)\s+(.+)\s*\(',
               '^(?:(?:\w+\s)*\w+),\s+(?:(?:\w+\s)*\w+)\s\s+(.+)\(also providing',
               '^(?:(?:\w+\s)*\w+),\s+(?:(?:\w+\s)*\w+)\s\s+(.+)\('
              #  r'^.+,\n.+\s+(.+)\s+\(also providing', r'^.+,\n.+\s+(.+)\s+\(',
              # ',\n?.+\xa0\xa0 ((?:\w+\s)*\w+)\s+(\(also providing written testimony\))?\s+\('
              ]
    for r in regexes:
        titleRe = re.compile(r)
        match = re.search(titleRe, line)
        if match:
            return match.group(1).strip()
    return None

def addOrg(line):
    """
    Takes in a string of text representing a line from a witness list file and, if it's able to identify
    the witness's organization, returns it as a string. Returns None otherwise.
    """
    
    flags = [re.IGNORECASE, re.DOTALL]
    regexes = [r'written testimony\)\s+\((.+)\)\s*(,|$)', 
              r'\s+\((.+)\)\s*(,|$)',]
    for f in flags:
        for r in regexes:
            orgRe = re.compile(r, f)
            match = re.search(orgRe, line)
            if match:
                return match.group(1).strip()
    return None

def addCity(line):
    """
    Takes in a string of text representing a line from a witness list file and, if it's able to identify
    the witness's city and state, returns a list containing a string for the last name and a string for the
    first name. The list contains "None" values otherwise.
    """
    
    extension = []
    cityRe = re.compile(r'\)\s?,\s(.*),\s(.*)$')
    match = re.search(cityRe, line)
    if match:
        return [match.group(1).strip(), match.group(2).strip()]
    return [None, None]

# %%
# I haven't made a corresponding function for Senate bills. Instead I
# reused this same function, which means the Senate data probably has
# more errors.

def HBWitness(witnessList):
    """
    Input is an HTML file from the Texas Legislature representing a witness list. The function iterates through
    the lines of HTML and populates a list with the lines representing witnesses. Each item in the list includes
    the text of the line of HTML, the word "For" "Against" or "On" depending on which section of the list the line
    came from, and the bill number. The function return the list.
    """
    
    fp = open(witnessList, encoding = 'cp1252')
    soup = BeautifulSoup(fp.read(), "html.parser")
    
    # each printed page has a class with Wordsection plus a number
    pages = soup.select("div[class^=WordSection]") 
    
    indent = re.compile(r"^\s{30}") # whitespace should mean it's a listing, page number, or the heading "WITNESS LIST"
    forStance = re.compile(r'^\s+FOR\s?:', re.IGNORECASE) # i flag means case-insensitive
    againstStance = re.compile(r'^\s+AGAINST\s?:', re.IGNORECASE)
    onStance = re.compile(r'^\s+ON\s?:', re.IGNORECASE)

    wit = []
    stance = "For"
    for page in pages:
        witpage = []
        pp = page.select("p")
        for line in pp:
            text = line.get_text()
            if re.match(forStance, text):
                stance = "For"
            if re.match(againstStance, text):
                stance = "Against"
            if re.match(onStance, text):
                stance = "On"
            if re.match(indent, text):
                witpage.append([line.get_text(), stance])
        wit.extend(witpage[1:-1])

    bill = soup.find('span', {'style':"color:windowtext;text-decoration:none"}) # identifies the bill
    bill = bill.get_text()
    for line in wit:
        line.extend([bill.strip()])
    
    wit = [x for x in wit if x != None]
    
    return wit

# %%
def mergelines(wit):
    """
    Input is a list of lists representing lines of text in a witness list document from the Legislature. 
    This function tries to determine whether whether consecutive lines refer to the same witness and need
    to be merged into one row of data. It returns a new list of lists, with those lines merged together.
    """
    
    changed = 0    
    newList = []
    badList = []
    tooShort = re.compile("^\w+\)?,?\s?(AL|AK|AS|AZ|AR|CA|CO|CT|DE|DC|FM|FL|GA|GU|HI|ID|IL\
                        |IN|IA|KS|KY|LA|ME|MH|MD|MA|MI|MN|MS|MO|MT|NE|NV|NH|NJ|NM|NY|NC\
                        |ND|MP|OH|OK|OR|PW|PA|PR|RI|SC|SD|TN|TX|Texas|UT|VT|VI|VA|WA|WV|WI|WY)?\n?$") # line shouldn't have just one word
    for row in wit:
        row[0] = row[0].strip()
    
    for row in wit[:-1]:
        lineIndex = wit.index(row)
        
        # Lines will get merged if they pass any of the three tests. Only if not will a line be accepted.
        
        if re.search(endWithState, wit[lineIndex + 1][0]) and not re.search(endWithState, row[0]) \
        and addName(row[0]) != [None, None] and addName(wit[lineIndex + 1][0]) == [None, None]:
            newList.append([row[0] + " " + wit[lineIndex + 1][0], row[1], row[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
        
        elif re.search(tooShort, wit[lineIndex + 1][0].strip()):
            newList.append([row[0] + " " + wit[lineIndex + 1][0], row[1], row[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
            
        elif row[0].count(')') != row[0].count('(') \
        and wit[lineIndex + 1][0].count(')') != wit[lineIndex + 1][0].count('(') \
        and addName(row[0]) != [None, None] and not re.search(endWithState, row[0]):
            newList.append([row[0] + " " + wit[lineIndex + 1][0], row[1], row[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
            
        elif row[0].count(')') != row[0].count('(') \
        and wit[lineIndex + 1][0].count(')') != wit[lineIndex + 1][0].count('(') \
        and addName(row[0]) != [None, None] \
        and addName(wit[lineIndex + 1][0]) == [None,None]:
            newList.append([row[0] + " " + wit[lineIndex + 1][0], row[1], row[2]])
            badList.append(wit[lineIndex + 1][0:3])
            changed += 1
            
        else:
            newList.append(row[0:3])
    
    answer = [x for x in newList if x not in badList]
    
    return answer

# %%
import shutil, os

def extractRows(folderName):
    """
    Input is the name of a folder full of witness list files. The function extracts the lines from each file,
    attempts to merge them into lists representing rows of data referring to one witness each, and returns 
    one long list of lists.
    """
    
    houseWit = []
    for folderName, subfolders, filenames in os.walk(folderName):
        for filename in filenames:
            if filename != ".DS_Store":
                source = folderName + filename
                wit = HBWitness(source)
                # trying to rejoin entries split across lines
                new = mergelines(wit)
                new = mergelines(new) # Will doing it twice catch 3-line entries?
                houseWit.extend(new)
    return houseWit
            
folderName = 'bills/85R/witlistbill/html/house_bills/'
houseWit = extractRows(folderName)

# %%
# Adding the last six fields to each row

def extendRow(row):
    """
    Input is a list representing a row of data about a witness. The function extends the list 
    with six more items and returns the extended list.
    """
    
    row.extend(addName(row[0]))
    row.append(addTitle(row[0]))
    row.append(addOrg(row[0]))
    row.extend(addCity(row[0]))
    return row

houseRows = [extendRow(row) for row in houseWit]

# %%
houseRows[:5]
# Out:
# [['Colyandro,\nJohn (Texas Conservative Coalition)',
#   'For',
#   'HB 3081',
#   'Colyandro',
#   'John',
#   None,
#   'Texas Conservative Coalition',
#   None,
#   None],
#  ['Minick,\nStephen (Texas Asssociation of Business)',
#   'For',
#   'HB 3081',
#   'Minick',
#   'Stephen',
#   None,
#   'Texas Asssociation of Business',
#   None,
#   None],
#  ['Norcross,\nRob (Consumer service alliance of texas)',
#   'For',
#   'HB 3081',
#   'Norcross',
#   'Rob',
#   None,
#   'Consumer service alliance of texas',
#   None,
#   None],
#  ['Scurlock,\nStephen (Independent Bankers Association of Texas)',
#   'For',
#   'HB 3081',
#   'Scurlock',
#   'Stephen',
#   None,
#   'Independent Bankers Association of Texas',
#   None,
#   None],
#  ['Allmon,\nJennifer (The Texas Catholic Conference of Bishops)',
#   'Against',
#   'HB 3081',
#   'Allmon',
#   'Jennifer',
#   None,
#   'The Texas Catholic Conference of Bishops',
#   None,
#   None]]

# %%
# pandas is only used for data exploration. 
# There are definitely still errors.

import pandas as pd
pd.options.display.max_colwidth = 500


df = pd.DataFrame(houseRows, columns=list(['raw', 'position', 'bill', 'last','first','title', 'org','city','state']))

# %%
# df[df['bill'] == "HB 3025"]

# %%
# These are the lines most likely to have problems

df[pd.isnull(df['org'])]
# df.first.isnull()
# Out:
#                                                                                                 raw  \
# 1289            Neavel,\nMD, Celia (Self; Texas Pediatric Society, Texas Medical Association, Texas
# 1290   Association\nof Obstretics and Gynecology, Texas Academy of Family Practice, March of Dimes)
# 1309                                       Academy\nof Family Physicians, MOD, TX Care for Childre)
# 2710       Neavel,\nCelia   Dr  (also providing written testimony)  (Self; Texas Pediatric Society,
# 2711          Texas\nMedical Asocciation, Texas Academy of Family Physicians, March of Dimes, Texas
# 2710                            Dr  None    None  None
# 2711                          None  None    None  None
# 2712                          None  None  Austin    TX
# 4004   Ambulatory Medical Director  None    None  None
# 4005                          None  None  Dallas    TX
# 8683                          None  None    None  None
# 10662                         None  None    None  None
# 10663                         None  None    None  None
# 10664                         None  None  Austin    TX
# 11637                         None  None    None  None
# 12001                         None  None    None  None
# 12504           Executive Director  None    None  None
# 12505                         None  None  Austin    TX
# 13230           Physical therapist  None    None  None
# 13231                         None  None  Dallas    TX
# 14697                         None  None    None  None
# 16589                         None  None    None  None
# 16624                         None  None    None  None
# 16625                         None  None    None  None
# 18377                         None  None    None  None
# 18378                         None  None    None  None
# 18408                         None  None    None  None
# 19741                         None  None    None  None
# 19742                         None  None    None  None

# %%
# df[df['bill'] == "HB 2"]

# %%
# Looking at a random sample

df.sample(n = 40)
# Out:
#                                                                                                                       raw  \
# 6957                                                                       Noble,\nShannon (Texas Counseling Association)
# 978                                                                     Lee,\nDonald (Texas Conference of Urban Counties)
# 17954                                                                                  Russell,\nClaudia (El Paso County)
# 9783                                                                                              Frandsen,\nChris (Self)
# 15549                                                  Skaggs,\nJason (Texas and Southwestern Cattle Raisers Association)
# 14688                                                                             Wachs,\nMichael    (Self) , Houston, TX
# 2300                                        Stevens,\nAlan (Baylor scott and white health and Texas hospital association)
# 1819                                                   Raun,\nLowell (Self; Texas rice producers group, coastal bend gcd)
# 13603                                                                       Arellano,\nRobert (Self; Tejano music awards)
# 21297                                                          Gustafson,\nLindsay (Texas Classroom Teachers Association)
# 8156                                                                                           Willette,\nLynnae (EDF-RE)
# 21494                                                           Place,\nShea (Texas Criminal Defense Lawyers Association)
# 10079                                                              Hinkle,\nDan (Association of Energy Service Companies)
# 2577                                                                          Hawkins,\nJohn (Texas Hospital Association)
# 9834                                                                                    Harris,\nDwight (Self; Texasaaft)
# 14588                                                       Kingsley,\nBernadette (Self; Texas School Nurse Organization)
# 9018                                                                   Gregg,\nBrock (Texas retired teachers association)
# 7629                                                                               McGarry,\nMignon    (RNDC), Austin, TX
# 12218  Cunningham,\nJames (Texas Coalition of Veterans Organizations and Military Officers Association\nof America Texas)
# 14158                                                            Frandsen,\nChris (Self; League of Women Voters of Texas)
# 8708                                Hansch,\nGreg    (Self; National Alliance on Mental Illness (NAMI) Texas), Austin, TX
# 11394                                                    Beene,\nJoleann (Self; Preferref Care Partners Management Group)
# 13466                                                                             Longley,\nBill (Texas municipal league)
# 16035                                                                     Stuckemeyer,\nJohn (Self; State Farm Insurance)
# 17995                                                       McCreary,\nCasey (Texas Association of School Administrators)
# 10873                                                                              Hudgens,\nNicole (Texas Values Action)
# 6530                                                                                            Parkinson,\nThomas (Self)
# 16964                            Smothermon,\nJennifer (Texas State Board of Examiners of Marriage and Family Therapists)
# 7566                                                                                              Obaseki,\nTyrone (Self)
# 17309                                                                         Mintz,\nDavid (Texas Apartment Association)
# 10434                                                                  Renaud,\nJorge (Self; Texas Advocates for Justice)
# 13440                                                                                        Banks,\nYannis (Texas NAACP)
# 6592                                         None
#
#                                                                                                  org  \
# 6957                                                                    Texas Counseling Association
# 978                                                               Texas Conference of Urban Counties
# 17954                                                                                 El Paso County
# 9783                                                                                            Self
# 15549                                              Texas and Southwestern Cattle Raisers Association
# 14688                                                                                           Self
# 2300                                    Baylor scott and white health and Texas hospital association
# 1819                                              Self; Texas rice producers group, coastal bend gcd
# 13603                                                                      Self; Tejano music awards
# 21297                                                           Texas Classroom Teachers Association
# 8156                                                                                          EDF-RE
# 21494                                                     Texas Criminal Defense Lawyers Association
# 10079                                                        Association of Energy Service Companies
# 2577                                                                      Texas Hospital Association
# 9834                                                                                 Self; Texasaaft
# 14588                                                          Self; Texas School Nurse Organization
# 9018                                                              Texas retired teachers association
# 7629                                                                                            RNDC
# 12218  Texas Coalition of Veterans Organizations and Military Officers Association\nof America Texas
# 14158                                                          Self; League of Women Voters of Texas
# 8708                                          Self; National Alliance on Mental Illness (NAMI) Texas
# 11394                                                 Self; Preferref Care Partners Management Group
# 13466                                                                         Texas municipal league
# 16035                                                                     Self; State Farm Insurance
# 17995                                                     Texas Association of School Administrators
# 10873                                                                            Texas Values Action
# 6530                                                                                            Self
# 16964                               Texas State Board of Examiners of Marriage and Family Therapists
# 7566                                                                                            Self
# 17309                                                                    Texas Apartment Association
# 10434                                                              Self; Texas Advocates for Justice
# 13440                                                                                    Texas NAACP
# 15708                                                                 Texas Construction Association
# 721                                                             Texas Department of Criminal Justice
# 19251                                                             Texas Economic Development Council
# 8674                                                          Texas Association of Community Schools
# 618                                                                         Self; Moms Demand Action
# 19998                                                       The Texas Catholic Conference of Bishops
# 14623                                                        TMPA Texas Municipal Police Association
# 6592                                                                                 Ensign Services
#
#           city state
# 6957      None  None
# 978       None  None
# 17954     None  None
# 9783      None  None
# 15549     None  None
# 14688  Houston    TX
# 2300      None  None
# 1819      None  None
# 13603     None  None
# 21297     None  None
# 8156      None  None
# 21494     None  None
# 10079     None  None
# 2577      None  None
# 9834      None  None
# 14588     None  None
# 9018      None  None
# 7629    Austin    TX
# 12218     None  None
# 14158     None  None
# 8708    Austin    TX
# 11394     None  None
# 13466     None  None
# 16035     None  None
# 17995     None  None
# 10873     None  None
# 6530      None  None
# 16964     None  None
# 7566      None  None
# 17309     None  None
# 10434     None  None
# 13440     None  None
# 15708     None  None
# 721       None  None
# 19251     None  None
# 8674    Austin    TX
# 618       None  None
# 19998     None  None
# 14623   Austin    TX
# 6592      None  None

# %%
def changeN(cell):
    if cell != None:
        cell = cell.replace("\n", " ")
    return cell
    
houseRows = [[changeN(cell) for cell in line] for line in houseRows]

# %%
import csv

def export(dir, witList):
    with open(dir,'w') as f:
        writer = csv.writer(f)
        writer.writerow(['FullText', 'Position', 'Bill', 'LastName', 'FirstName', 'Role', 'Organization', 'City', 'State'])
        writer.writerows(witList) # better just to include the FullText field.
    return None

houseDir = '../data/witness-lists/HouseWitness.csv'
export(houseDir, houseRows)

# %%
# duplicating the House process for the Senate

folderName = 'bills/85R/witlistbill/html/senate_bills/'
senateWit = extractRows(folderName)
senList = [extendRow(row) for row in senateWit]
senList = [[changeN(cell) for cell in row] for row in senList]

# %%
senateDir = '../data/witness-lists/SenateWitness.csv'
export(senateDir, senList)

# %%
# Just looking at a sample of the data. Maybe 95% correct.

sen = pd.DataFrame(senList, columns=list(['raw', 'position', 'bill', 'last','first','title', 'org','city','state']))
sen.sample(n = 40)
# Out:
#                                                                                                                                                                       raw  \
# 5456                                                                                                             Stewart, Kevin    (Texas Nurses Association), Austin, TX
# 7832                                                                                                       Freeman, Ray   Executive Director  (Equity Center), Austin, TX
# 16906                                                                                                       Gore, Rex   Citizen/Charter board member  (Self) , Austin, TX
# 15850                                                                                                                             Sanders, Cynthia    (Self) , Austin, TX
# 15588                                                                                                                                 Moehnke, Amy    (Self) , Austin, TX
# 6445                                                                                    Kelley, Scott   Executive Vice Chancellor  (UT System Administration), Austin, TX
# 11524                                                                                                                          Banks, Yannis    (Texas NAACP), Austin, TX
# 6734                                                                                    Dell'Antonio, Andrew   University Professor  (Myself and my daughter), Round Rock
# 12738                                                                                  Lee, Donald   Executive Director  (Texas Conference of Urban Counties), Austin, TX
# 13331                                                                                             Rau, Seth   Legislative Coordinator  (San Antonio ISD), San Antonio, TX
# 6114                                                                                                                               Arnold, Ellen   Consultant  (TX P.T.A)
# 2849                                                                     Bow, Claire   Attorney at Law  (Self, Transgender Education Network of Texas (TENT)), Austin, TX
# 914                                                                                                                                                  Miller, Grace (Self)
# 3631                                                                                                                                Duble, Steven    (Self) , Houston, TX
# 10457                                                                                                                  Shetter, Ken   Mayor  (Burleson, Tx), Burleson, TX
# 12901                                                                                                        Keener, Justin    (Americans for Prosperity - Texas), Austin
# 6438                                    Fowle, Dr, Marilyn   V.P. for Adm. & Finance  (also providing written testimony) (Midwestern State University), Wichita Falls, TX
# 16908                                                                                                                          Banks, Yannis    (Texas NAACP), Austin, TX
# 12640                                                                                                      Ozuna, Jesse    (Mayor's Office, City of Houston), Houston, TX
# 13066                                                                            Williams, Ellen   Consultant/attorney  (Houston Independent School District), Austin, TX
# 1127                                                                                                                                              Morrison, Kristi (Self)
# 16799                                                                                                                             Scott, Elizabeth    (Self) , Austin, TX
# 14165                                                                                        Flores, Juan Antonio   EVP Govt Affairs  (Port San Antonio), San Antonio, TX
# 2801                                                                                                                      Dixon, Don   Engineer  (Self) , San Antonio, TX
# 10248                                                                                           Alfred, Everette D.    (North & East TX County Judge & Commissioner Ass.)
# 2745   Gravell, Bill   Judge-JP pct. 3, Williamson County  (also providing written testimony) (Self; Justices of the Peace and Constables Assc. Of Texas), Georgetown, TX
# 11456                                                                                                                                           Mamikonian, Adrian (Self)
# 4523                                                                                                                               Venglar, Leslie    (Self) , Austin, TX
# 3053                                                                                                        Shumway, Loren   Cyber Security Manager  (Self) , Houston, TX
# 14954                                                                                                                            Castro, Christine    (Self) , Austin, TX
# 10576                                                                                                          Zavala, Ofelia   San Jose parishioner  (Self) , Austin, TX
# 16414                                                                                                                           Deotte, Richard    (Self) , Southlake, TX
# 10248                                                              D.
# 2745                               Judge-JP pct. 3, Williamson County
# 11456                                                            None
# 4523
# 3053                                           Cyber Security Manager
# 14954
# 10576                                            San Jose parishioner
# 16414
# 10849                                                         Officer
# 14074                                                            None
# 16518
# 283                                                               CEO
# 14360                                              Executive Director
# 15139                                                        Reverend
# 7616                                                             Mrs.
# 16874
#
#                                                                                org  \
# 5456                                                      Texas Nurses Association
# 7832                                                                 Equity Center
# 16906                                                                         Self
# 15850                                                                         Self
# 15588                                                                         Self
# 6445                                                      UT System Administration
# 11524                                                                  Texas NAACP
# 6734                                                        Myself and my daughter
# 12738                                           Texas Conference of Urban Counties
# 13331                                                              San Antonio ISD
# 6114                                                                      TX P.T.A
# 2849                                                                         TENT)
# 914                                                                           Self
# 3631                                                                          Self
# 10457                                                                 Burleson, Tx
# 12901                                             Americans for Prosperity - Texas
# 6438                                                   Midwestern State University
# 16908                                                                  Texas NAACP
# 12640                                              Mayor's Office, City of Houston
# 13066                                          Houston Independent School District
# 1127                                                                          Self
# 16799                                                                         Self
# 14165                                                             Port San Antonio
# 2801                                                                          Self
# 10248                             North & East TX County Judge & Commissioner Ass.
# 2745                     Self; Justices of the Peace and Constables Assc. Of Texas
# 11456                                                                         Self
# 4523                                                                          Self
# 3053                                                                          Self
# 14954                                                                         Self
# 10576                                                                         Self
# 16414                                                                         Self
# 10849                                        Houston Police Officer Pension System
# 14074                                                       Texas Education Agency
# 16518                                                                  Self; TARAL
# 283    Texas Statewide Telephone Cooperative, Inc. and Texas Telephone Association
# 14360                                             Texas Conference of Urban County
# 15139                                                      Self; Austin Interfaith
# 7616                                                                          Self
# 16874                                                 Self; Abolish Abortion Texas
#
#                 city state
# 5456          Austin    TX
# 7832          Austin    TX
# 16906         Austin    TX
# 15850         Austin    TX
# 15588         Austin    TX
# 6445          Austin    TX
# 11524         Austin    TX
# 6734            None  None
# 12738         Austin    TX
# 13331    San Antonio    TX
# 6114            None  None
# 2849          Austin    TX
# 914             None  None
# 3631         Houston    TX
# 10457       Burleson    TX
# 12901           None  None
# 6438   Wichita Falls    TX
# 16908         Austin    TX
# 12640        Houston    TX
# 13066         Austin    TX
# 1127            None  None
# 16799         Austin    TX
# 14165    San Antonio    TX
# 2801     San Antonio    TX
# 10248           None  None
# 2745      Georgetown    TX
# 11456           None  None
# 4523          Austin    TX
# 3053         Houston    TX
# 14954         Austin    TX
# 10576         Austin    TX
# 16414      Southlake    TX
# 10849         Conroe    TX
# 14074           None  None
# 16518         Austin    TX
# 283     Raymondville    TX
# 14360         Austin    TX
# 15139      Austin Tx    TX
# 7616        La Porte    TX
# 16874         Temple    TX

# %%
sen.describe()
# Out:
#                                                raw position   bill   last  \
# count                                        17035    17035  17035  16641
# unique                                       12500        3    827   5304
# top     Banks, Yannis    (Texas NAACP), Austin, TX  Against   SB 4  Smith
# freq                                            34     7825   2354    154
#
#         first  title    org    city  state
# count   16610  15141  16883   14267  14267
# unique   2607   3014   4623     799     33
# top      John          Self  Austin     TX
# freq      278   6904   5990    8272  14165
